# %% [markdown]
# # 이름 수정하고 질문 한번에

# %%
import pandas as pd
qa_all= pd.read_csv('/content/drive/MyDrive/AntHouse/0.Data/enterprise/kospi200_50/new/kospi_50.csv')
qa_all.drop(columns='ticker', inplace=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def naming_all(df,n): #n은 시작할 번호 0~시작
    cnt=0
    num= df.shape[0]
    print("0은 네이밍 시작, 1은 네이밍 종료, 2는 pass 입니다.")
    print('회사당 2개의 네이밍을 진행해주세요.')
    for i in range(n,df.shape[0]):
        print(df.iloc[i,0],'의 네이밍 여부를 선택해주세요.')
        # yn = input('숫자 : ')
        
        # if yn == '2':  # 다음기업 이동
        #     continue
        # elif yn=='1': # 네이밍 종료
        #     break
        # elif yn=='0': # 네이밍 하기 
        for _ in range(2):
            name = input()
            if name=='.': # 해당 턴 종료
                break
            else:
                ls=list(qa_all.iloc[i][1:])
                name = name+f'({df.iloc[i,0]})'
                ls.insert(0,name)
                # print(cnt)
                df.loc[cnt+num] = ls #맨 끝에 누적으로 추가
                # print(cnt+num)
                cnt += 1
    return df

# %%
naming_all(qa_all,0)

# %%
qa_all
# Out:
#                         name  매출액(억원) 영업이익(억원)  당기순이익(억원) 영업이익률(%) 순이익률(%)  \
# 0                       삼성전자  3054876   463279     371012    15.17   12.14
# 1                   LG에너지솔루션   251891    14273       9004     5.67    3.57
# 2                     SK하이닉스   450663    75122      50179    16.67   11.13
# 3                   삼성바이오로직스    27487     9093       6102    33.08    22.2
# 4                       LG화학   527186    33343      27163     6.33    5.15
# ..                       ...      ...      ...        ...      ...     ...
# 145            엘지 이노텍(LG이노텍)   195763    15328      10814     7.83    5.52
# 146            롯데 케미칼(롯데케미칼)   224089    -4893        591    -2.18    0.26
# 147              롯데케미(롯데케미칼)   224089    -4893        591    -2.18    0.26
# 148       에스케이바이오(SK바이오사이언스)     4835     1569       1332    32.45   27.55
# 149  에스케이 바이오사이언스(SK바이오사이언스)     4835     1569       1332    32.45   27.55
#
# ...

# %%
qa_all.to_csv('/content/drive/MyDrive/Colab Notebooks/자연어프로젝트/kospi_50_naming.csv', index=False
# Out:
#                         name  매출액(억원) 영업이익(억원)  당기순이익(억원) 영업이익률(%) 순이익률(%)  \
# 0                       삼성전자  3054876   463279     371012    15.17   12.14
# 1                   LG에너지솔루션   251891    14273       9004     5.67    3.57
# 2                     SK하이닉스   450663    75122      50179    16.67   11.13
# 3                   삼성바이오로직스    27487     9093       6102    33.08    22.2
# 4                       LG화학   527186    33343      27163     6.33    5.15
# ..                       ...      ...      ...        ...      ...     ...
# 145            엘지 이노텍(LG이노텍)   195763    15328      10814     7.83    5.52
# 146            롯데 케미칼(롯데케미칼)   224089    -4893        591    -2.18    0.26
# 147              롯데케미(롯데케미칼)   224089    -4893        591    -2.18    0.26
# 148       에스케이바이오(SK바이오사이언스)     4835     1569       1332    32.45   27.55
# 149  에스케이 바이오사이언스(SK바이오사이언스)     4835     1569       1332    32.45   27.55
#
# ...
