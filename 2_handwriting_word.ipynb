# %% [markdown]
# <a href="https://colab.research.google.com/github/Solxcero/_SeSac_/blob/main/2_handwriting_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 필요라이브러리

# %%
import json
import random
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# %cd /content
# !git clone 'https://github.com/Solxcero/-deep-text-recognition-benchmark.git'
# %cd /content/-deep-text-recognition-benchmark/

# !mkdir data
# !mkdir /content/-deep-text-recognition-benchmark/data/train
# !mkdir /content/-deep-text-recognition-benchmark/data/test
# !mkdir /content/-deep-text-recognition-benchmark/data/validation

# !unzip '/content/drive/MyDrive/project/hadwriting/01_handwriting_word_images.zip' -d ./data/

# %%
# %cd /content/-deep-text-recognition-benchmark/

# !mkdir saved_models_1

# %%
# !mkdir /content/-deep-text-recognition-benchmark/saved_models_1/TPS-ResNet-BiLSTM-CTC-Seed1111_1

# %%
file = json.load(open('/content/drive/MyDrive/project/hadwriting/handwriting_data_info_clean.json'))
file.keys() #dict_keys(['info', 'images', 'annotations', 'licenses'])
file['info']
# Out:
# {'name': '한글 손글씨 데이터', 'date_created': '2019-09-18 04:45:22'}

# %%
words = [f for f in file['annotations'] if f['attributes']['type']=='단어(어절)']
print(f'단어(어절) 데이터 : {len(words)}')
# Out:
# 단어(어절) 데이터 : 359997

# %%
0.4/8
# Out:
# 0.05

# %%
# import random
# import os

ocr_words_files = os.listdir('/content/-deep-text-recognition-benchmark/data/1_word/')
# len(ocr_words_files) # 359997

#1000고정
random.seed(1000)
random.shuffle(ocr_words_files)

#8:2 맞추기
n_train = int(len(ocr_words_files) * 0.1)
n_validation = int(len(ocr_words_files) * 0.0125)  #
n_test = int(len(ocr_words_files) * 0.0125)

n_train_2 = int(len(ocr_words_files) * 0.2)
n_validation_2 = int(len(ocr_words_files) * 0.05)  #
n_test_2 = int(len(ocr_words_files) * 0.005)


print(f'train_1 : {n_train}\nvalidation_1 : {n_validation}\ntest_1 : {n_test}') #
print(f'sum_1 : {n_train+n_validation+n_test}\n\n')

print(f'train_2 : {n_train_2}\nvalidation_2 : {n_validation_2}\ntest_2 : {n_test_2}\n\n') #


print(f'train추가 : {n_train_2-n_train}\nvalidation추가 : {n_validation_2-n_validation}')
print(f'sum_2 : {n_train_2-n_train+n_validation_2-n_validation}')
# Out:
# train_1 : 35999
# validation_1 : 4499
# test_1 : 4499
# sum_1 : 44997
#
#
# train_2 : 71999
# validation_2 : 17999
# test_2 : 1799
#
#
# train추가 : 36000
# validation추가 : 13500
# sum_2 : 49500

# %%
n_train_2 > n_train+n_validation
# Out:
# True

# %%
train_files_1 = ocr_words_files[:n_train]
validation_files_1 = ocr_words_files[n_train: n_train+n_validation]
test_files_1 = ocr_words_files[-n_test:]

train_files_2 = ocr_words_files[n_train+n_validation:n_train_2+n_validation]
validation_files_2 = ocr_words_files[n_train_2+n_validation: n_train_2+n_validation_2]
test_files_2 = ocr_words_files[-n_test_2:]


print(f'train_files : {len(train_files_2)}\nvalidation_files : {len(validation_files_2)}')
# Out:
# train_files : 36000
# validation_files : 13500

# %%
import pandas as pd
mat = pd.DataFrame({'1':train_files_1[-10:],'2': reversed(train_files_2[:10])})
mat['f/t'] = mat['1'] == mat['2']
mat
# Out:
#               1             2    f/t
# 0  00426349.png  00868318.png  False
# 1  00577482.png  00925780.png  False
# 2  00871889.png  00368556.png  False
# 3  00334229.png  00221404.png  False
# 4  01013598.png  00433911.png  False
# 5  00808596.png  00431355.png  False
# 6  00828383.png  00463330.png  False
# 7  00695898.png  01069169.png  False
# 8  00052883.png  00647311.png  False
# 9  00463991.png  00051955.png  False

# %%
# from tqdm import tqdm
# %cd /content/-deep-text-recognition-benchmark/data/

## train/validation/test 이미지들에 해당하는 id 값을 저장

train_img_ids = {}
validation_img_ids = {}
test_img_ids = {}

for image in tqdm(file['images'],desc='id 저장'):
    if image['file_name'] in train_files_2:
        train_img_ids[image['file_name']] = image['id']
    elif image['file_name'] in validation_files_2:
        validation_img_ids[image['file_name']] = image['id']
    elif image['file_name'] in test_files_2:
        test_img_ids[image['file_name']] = image['id']

## train/validation/test 이미지들에 해당하는 annotation 들을 저장

train_annotations = {f:[] for f in train_img_ids.keys()}
validation_annotations = {f:[] for f in validation_img_ids.keys()}
test_annotations = {f:[] for f in test_img_ids.keys()}

train_ids_img = {train_img_ids[id_]:id_ for id_ in train_img_ids}
validation_ids_img = {validation_img_ids[id_]:id_ for id_ in validation_img_ids}
test_ids_img = {test_img_ids[id_]:id_ for id_ in test_img_ids}

for idx, annotation in tqdm(enumerate(file['annotations']),desc='annotation 저장'):
    # if idx % 5000 == 0:
        # print(idx,'/',len(file['annotations']),'processed')
    if annotation['attributes']['type'] != '단어(어절)': #단어 타입이 아니면
        continue
    if annotation['image_id'] in train_ids_img:
        train_annotations[train_ids_img[annotation['image_id']]].append(annotation)
    elif annotation['image_id'] in validation_ids_img:
        validation_annotations[validation_ids_img[annotation['image_id']]].append(annotation)
    elif annotation['image_id'] in test_ids_img:
        test_annotations[test_ids_img[annotation['image_id']]].append(annotation)

with open('train_annotation.json', 'w') as file:
    json.dump(train_annotations, file)
with open('validation_annotation.json', 'w') as file:
    json.dump(validation_annotations, file)
with open('test_annotation.json', 'w') as file:
    json.dump(test_annotations, file)
# Out:
# /content/-deep-text-recognition-benchmark/data
# id 저장: 100%|██████████| 1142045/1142045 [32:00<00:00, 594.74it/s]
# annotation 저장: 1142045it [00:00, 1530547.93it/s]

# %%
# import json
# import os
# import cv2
# import matplotlib.pyplot as plt
# from tqdm import tqdm

## aihub 데이터 annotation을 읽어서 단어 단위로 잘라서 data에 저장하기

data_root_path = '/content/-deep-text-recognition-benchmark/data/1_word/'
save_root_path = '/content/-deep-text-recognition-benchmark/data/'

test_annotations = json.load(open('/content/-deep-text-recognition-benchmark/data/test_annotation.json'))
gt_file = open(save_root_path+'gt_test.txt', 'w')
for file_name in tqdm(test_annotations,desc='test'):
    annotations = test_annotations[file_name]
    image = cv2.imread(data_root_path+file_name)    
    text = annotations[0]['text']      
    cv2.imwrite(save_root_path+'test/'+file_name,image)
    gt_file.write("test/{}\t{}\n".format(file_name, text))

validation_annotations = json.load(open('/content/-deep-text-recognition-benchmark/data/validation_annotation.json'))
gt_file = open(save_root_path+'gt_validation.txt', 'w')
for file_name in tqdm(validation_annotations,desc='validation'):
    annotations = validation_annotations[file_name]
    image = cv2.imread(data_root_path+file_name)    
    text = annotations[0]['text']       
    cv2.imwrite(save_root_path+'validation/'+file_name,image )
    gt_file.write("validation/{}\t{}\n".format(file_name, text))
        
train_annotations = json.load(open('/content/-deep-text-recognition-benchmark/data/train_annotation.json'))
gt_file = open(save_root_path+'gt_train.txt', 'w')
for file_name in tqdm(train_annotations,desc='train'):
    annotations = train_annotations[file_name]
    image = cv2.imread(data_root_path+file_name)   
    text = annotations[0]['text']       
    cv2.imwrite(save_root_path+'train/'+file_name,image)
    gt_file.write("train/{}\t{}\n".format(file_name, text))
# Out:
# test: 100%|██████████| 1799/1799 [00:06<00:00, 262.32it/s]
# validation: 100%|██████████| 13500/13500 [00:43<00:00, 310.34it/s]
# train: 100%|██████████| 36000/36000 [01:53<00:00, 316.16it/s]

# %%
# !pip install lmdb
# !pip install fire
import fire
import cv2
import lmdb,torch,torchvision, nltk ,natsort
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lmdb in /usr/local/lib/python3.8/dist-packages (0.99)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 3.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from fire) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from fire) (2.1.1)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=96f40c1f7faa74123c83aff4f618e03bf7a880a59fc8ef7a6a2f7a23488a42cb
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
# Successfully built fire
# Installing collected packages: fire
# Successfully installed fire-0.5.0

# %%
# %cd /content/-deep-text-recognition-benchmark
# Out:
# /content/-deep-text-recognition-benchmark

# %%
# !python create_lmdb_dataset.py --inputPath data/ --gtFile data/gt_train.txt --outputPath data_lmdb/train
# !python create_lmdb_dataset.py --inputPath data/ --gtFile data/gt_validation.txt --outputPath data_lmdb/validation

# !python create_lmdb_dataset.py --inputPath data/ --gtFile data/gt_test.txt --outputPath data_lmdb/test
# Out:
# Created dataset with 35805 samples
# Created dataset with 13500 samples

# %%
# %%time
# !CUDA_VISIBLE_DEVICES=0,1,2 python3 train.py --train_data data_lmdb/train --valid_data data_lmdb/validation \
	--saved_model /content/drive/MyDrive/project/handwriting_code/best_accuracy.pth \
	--num_iter 20000 --valInterval 2500 \
	--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
	--data_filtering_off --workers 0 --imgH 64 --imgW 200
# Out:
# --------------------------------------------------------------------------------
# dataset_root: data_lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 35805
# num total samples of /: 35805 x 1.0 (total_data_usage_ratio) = 35805
# num samples of / per batch: 64 x 1.0 (batch_ratio) = 64
# --------------------------------------------------------------------------------
# Total_batch_size: 64 = 64
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb/validation	 dataset: /
# sub-directory:	/.	 num samples: 13500
# --------------------------------------------------------------------------------
# model input parameters 64 200 20 1 512 256 1047 50 TPS ResNet BiLSTM CTC
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# loading pretrained model from /content/drive/MyDrive/project/handwriting_code/best_accuracy.pth
# Model:
# DataParallel(
#   (module): Model(
#     (Transformation): TPS_SpatialTransformerNetwork(
#       (LocalizationNetwork): LocalizationNetwork(
#         (conv): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (10): ReLU(inplace=True)
#           (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (14): ReLU(inplace=True)
#           (15): AdaptiveAvgPool2d(output_size=1)
#         )
#         (localization_fc1): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (localization_fc2): Linear(in_features=256, out_features=40, bias=True)
#       )
#       (GridGenerator): GridGenerator()
#     )
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=1047, bias=True)
#   )
# )
# Trainable params num :  49117663
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     foreach: None
#     lr: 1
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# exp_name: TPS-ResNet-BiLSTM-CTC-Seed1111
# train_data: data_lmdb/train
# valid_data: data_lmdb/validation
# manualSeed: 1111
# workers: 0
# batch_size: 64
# num_iter: 20000
# valInterval: 2500
# saved_model: /content/drive/MyDrive/project/handwriting_code/best_accuracy.pth
# FT: False
# adam: False
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: False
# select_data: ['/']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 50
# imgH: 64
# imgW: 200
# rgb: False
# character: 0123456789abcdefghijklmnopqrstuvwxyz0123456789abcdefghijklmnopqrstuvwxyz가각간갇갈감갑값갓강갖같갚갛개객걀걔거걱건걷걸검겁것겉게겨격겪견결겹경곁계고곡곤곧골곰곱곳공과관광괜괴굉교구국군굳굴굵굶굽궁권귀귓규균귤그극근글긁금급긋긍기긴길김깅깊까깍깎깐깔깜깝깡깥깨꺼꺾껌껍껏껑께껴꼬꼭꼴꼼꼽꽂꽃꽉꽤꾸꾼꿀꿈뀌끄끈끊끌끓끔끗끝끼낌나낙낚난날낡남납낫낭낮낯낱낳내냄냇냉냐냥너넉넌널넓넘넣네넥넷녀녁년념녕노녹논놀놈농높놓놔뇌뇨누눈눕뉘뉴늄느늑는늘늙능늦늬니닐님다닥닦단닫달닭닮담답닷당닿대댁댐댓더덕던덜덟덤덥덧덩덮데델도독돈돌돕돗동돼되된두둑둘둠둡둥뒤뒷드득든듣들듬듭듯등디딩딪따딱딴딸땀땅때땜떠떡떤떨떻떼또똑뚜뚫뚱뛰뜨뜩뜯뜰뜻띄라락란람랍랑랗래랜램랫략량러럭런럴럼럽럿렁렇레렉렌려력련렬렵령례로록론롬롭롯료루룩룹룻뤄류륙률륭르른름릇릎리릭린림립릿링마막만많말맑맘맙맛망맞맡맣매맥맨맵맺머먹먼멀멈멋멍멎메멘멩며면멸명몇모목몬몰몸몹못몽묘무묵묶문묻물뭄뭇뭐뭘뭣므미민믿밀밉밌및밑바박밖반받발밝밟밤밥방밭배백뱀뱃뱉버번벌범법벗베벤벨벼벽변별볍병볕보복볶본볼봄봇봉뵈뵙부북분불붉붐붓붕붙뷰브븐블비빌빔빗빚빛빠빡빨빵빼뺏뺨뻐뻔뻗뼈뼉뽑뿌뿐쁘쁨사삭산살삶삼삿상새색샌생샤서석섞선설섬섭섯성세섹센셈셋셔션소속손솔솜솟송솥쇄쇠쇼수숙순숟술숨숫숭숲쉬쉰쉽슈스슨슬슴습슷승시식신싣실싫심십싯싱싶싸싹싼쌀쌍쌓써썩썰썹쎄쏘쏟쑤쓰쓴쓸씀씌씨씩씬씹씻아악안앉않알앓암압앗앙앞애액앨야약얀얄얇양얕얗얘어억언얹얻얼엄업없엇엉엊엌엎에엔엘여역연열엷염엽엿영옆예옛오옥온올옮옳옷옹와완왕왜왠외왼요욕용우욱운울움웃웅워원월웨웬위윗유육율으윽은을음응의이익인일읽잃임입잇있잊잎자작잔잖잘잠잡잣장잦재쟁쟤저적전절젊점접젓정젖제젠젯져조족존졸좀좁종좋좌죄주죽준줄줌줍중쥐즈즉즌즐즘증지직진질짐집짓징짙짚짜짝짧째쨌쩌쩍쩐쩔쩜쪽쫓쭈쭉찌찍찢차착찬찮찰참찻창찾채책챔챙처척천철첩첫청체쳐초촉촌촛총촬최추축춘출춤춥춧충취츠측츰층치칙친칠침칫칭카칸칼캄캐캠커컨컬컴컵컷케켓켜코콘콜콤콩쾌쿄쿠퀴크큰클큼키킬타탁탄탈탑탓탕태택탤터턱턴털텅테텍텔템토톤톨톱통퇴투툴툼퉁튀튜트특튼튿틀틈티틱팀팅파팎판팔팝패팩팬퍼퍽페펜펴편펼평폐포폭폰표푸푹풀품풍퓨프플픔피픽필핏핑하학한할함합항해핵핸햄햇행향허헌험헤헬혀현혈협형혜호혹혼홀홈홉홍화확환활황회획횟횡효후훈훌훔훨휘휴흉흐흑흔흘흙흡흥흩희흰히힘?!
# sensitive: False
# PAD: False
# data_filtering_off: True
# Transformation: TPS
# FeatureExtraction: ResNet
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# num_gpu: 1
# num_class: 1047
# ---------------------------------------
#
# [1/20000] Train loss: 0.31270, Valid loss: 0.20291, Elapsed_time: 6.73617
# Current_accuracy : 91.015, Current_norm_ED  : 0.96
# Best_accuracy    : 91.015, Best_norm_ED     : 0.96
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 걷기                        | 걷기                        | 0.9294	True
# 급하다                       | 급하다                       | 0.5145	True
# 어둡다                       | 어둡다                       | 0.8810	True
# 포크                        | 포크                        | 0.8660	True
# 얼굴                        | 얼굴                        | 0.8743	True
# --------------------------------------------------------------------------------
# [2500/20000] Train loss: 0.13242, Valid loss: 0.14883, Elapsed_time: 767.86122
# Current_accuracy : 93.252, Current_norm_ED  : 0.97
# Best_accuracy    : 93.252, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 어째서                       | 어째서                       | 0.8843	True
# 평가                        | 평가                        | 0.9145	True
# 미사일                       | 미사일                       | 0.9847	True
# 조각                        | 조각                        | 0.9892	True
# 제한하다                      | 제한하다                      | 0.9715	True
# --------------------------------------------------------------------------------
# [5000/20000] Train loss: 0.04968, Valid loss: 0.13242, Elapsed_time: 1527.39851
# Current_accuracy : 94.237, Current_norm_ED  : 0.97
# Best_accuracy    : 94.237, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 소시지                       | 소시지                       | 0.9834	True
# 선생                        | 선생                        | 0.9975	True
# 표면                        | 표면                        | 0.9529	True
# 빠뜨리다                      | 빠뜨리다                      | 0.7366	True
# 능동적                       | 능동적                       | 0.9844	True
# --------------------------------------------------------------------------------
# [7500/20000] Train loss: 0.02277, Valid loss: 0.10317, Elapsed_time: 2285.77650
# Current_accuracy : 95.593, Current_norm_ED  : 0.98
# Best_accuracy    : 95.593, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 발가락                       | 발가락                       | 0.9944	True
# 뜨다                        | 뜨다                        | 0.9976	True
# 알아듣다                      | 알아듣다                      | 0.9632	True
# 이월                        | 이월                        | 0.9999	True
# 궁금하다                      | 궁금하다                      | 0.9311	True
# --------------------------------------------------------------------------------
# [10000/20000] Train loss: 0.01256, Valid loss: 0.09532, Elapsed_time: 3044.81369
# Current_accuracy : 95.985, Current_norm_ED  : 0.98
# Best_accuracy    : 95.985, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 장난                        | 장난                        | 0.9993	True
# 강변                        | 강변                        | 0.9990	True
# 한둘                        | 한둘                        | 0.9973	True
# 통화                        | 통화                        | 0.9995	True
# 균형                        | 전경                        | 0.2548	False
# --------------------------------------------------------------------------------
# [12500/20000] Train loss: 0.00687, Valid loss: 0.08821, Elapsed_time: 3803.33380
# Current_accuracy : 96.511, Current_norm_ED  : 0.98
# Best_accuracy    : 96.511, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 얻다                        | 얻다                        | 0.9964	True
# 동작                        | 동작                        | 0.9999	True
# 벗다                        | 벗다                        | 0.9955	True
# 곧바로                       | 곧바로                       | 0.9984	True
# 빠르다                       | 빠르다                       | 0.5849	True
# --------------------------------------------------------------------------------
# [15000/20000] Train loss: 0.00295, Valid loss: 0.07828, Elapsed_time: 4562.36557
# Current_accuracy : 97.052, Current_norm_ED  : 0.99
# Best_accuracy    : 97.052, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 꼽히다                       | 꼽히다                       | 0.9981	True
# 임신                        | 임신                        | 0.8542	True
# 적절하다                      | 적절하다                      | 0.9958	True
# 콩                         | 콩                         | 0.9999	True
# 스키                        | 스키                        | 0.9994	True
# --------------------------------------------------------------------------------
# [17500/20000] Train loss: 0.00424, Valid loss: 0.09950, Elapsed_time: 5320.85465
# Current_accuracy : 95.874, Current_norm_ED  : 0.98
# Best_accuracy    : 97.052, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 나이                        | 나이                        | 0.9998	True
# 엉망                        | 엉망                        | 0.9968	True
# 입력                        | 입력                        | 0.9997	True
# 심정                        | 심정                        | 0.9987	True
# 지나다                       | 지나다                       | 0.9998	True
# --------------------------------------------------------------------------------
# [20000/20000] Train loss: 0.00550, Valid loss: 0.09038, Elapsed_time: 6077.60727
# Current_accuracy : 96.467, Current_norm_ED  : 0.98
# Best_accuracy    : 97.052, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 높아지다                      | 높아지다                      | 0.9020	True
# 허가                        | 숙가                        | 0.9082	False
# 엄청나다                      | 엄청나다                      | 0.9965	True
# 광고                        | 광고                        | 0.9997	True
# 대출                        | 대출                        | 0.9998	True
# --------------------------------------------------------------------------------
# end the training
# CPU times: user 23.1 s, sys: 3.82 s, total: 27 s
# Wall time: 1h 42min 24s

# %% [markdown]
# ## Test

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2 python3 demo.py --image_folder data/test --saved_model /content/-deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
    --workers 0 --batch_max_length 50 --imgH 64 --imgW 200
# Out:
# model input parameters 64 200 20 1 512 256 1047 50 TPS ResNet BiLSTM CTC
# loading pretrained model from /content/-deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00012897.png   	갑                        	0.8917
# data/test/00012923.png   	강화하다                     	0.3783
# data/test/00013041.png   	그이                       	0.9914
# data/test/00013056.png   	수십                       	0.9929
# data/test/00013071.png   	수집하다                     	0.7322
# data/test/00013252.png   	훈전                       	0.3031
# data/test/00013302.png   	부드럽다                     	0.9030
# data/test/00013385.png   	나오다                      	0.9646
# data/test/00013531.png   	둘                        	0.8350
# data/test/00013541.png   	뒤지다                      	0.8041
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00017590.png   	시집                       	0.9955
# data/test/00017735.png   	침작                       	0.3065
# data/test/00017763.png   	사진                       	0.9946
# data/test/00017787.png   	살림                       	0.9870
# data/test/00017831.png   	상점                       	0.8717
# data/test/00017984.png   	연두색                      	0.8014
# data/test/00017986.png   	연락처                      	0.9827
# data/test/00018001.png   	연출                       	0.9868
# data/test/00018076.png   	틀                        	0.9871
# data/test/00018113.png   	팩시밀리                     	0.6391
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00056058.png   	삶다                       	0.9005
# data/test/00056108.png   	비월                       	0.8399
# data/test/00056268.png   	열                        	0.9793
# data/test/00056630.png   	명절                       	0.9897
# data/test/00056651.png   	모양                       	0.9959
# data/test/00056669.png   	목요일                      	0.9815
# data/test/00056693.png   	감수성                      	0.9731
# data/test/00056791.png   	그날                       	0.9974
# data/test/00056803.png   	그래                       	0.9970
# data/test/00056835.png   	그림                       	0.9960
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00062083.png   	명함                       	0.7280
# data/test/00062101.png   	모시다                      	0.9603
# data/test/00062111.png   	모집하다                     	0.6300
# data/test/00062273.png   	스유                       	0.8023
# data/test/00062297.png   	승리                       	0.9892
# data/test/00062380.png   	서적                       	0.9974
# data/test/00062414.png   	보조                       	0.9807
# data/test/00062430.png   	복습                       	0.9790
# data/test/00062472.png   	부문                       	0.9995
# data/test/00062518.png   	끝없다                      	0.9659
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00066073.png   	이런저럼                     	0.2093
# data/test/00066081.png   	이룩하다                     	0.8894
# data/test/00066083.png   	이르다                      	0.9606
# data/test/00066198.png   	킬로                       	0.5193
# data/test/00066388.png   	기념                       	0.9977
# data/test/00066454.png   	시작                       	0.9910
# data/test/00066458.png   	시절                       	0.9988
# data/test/00066526.png   	지다                       	0.9998
# data/test/00066686.png   	상당수                      	0.9871
# data/test/00066769.png   	사                        	0.9992
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00073489.png   	건조하다                     	0.8838
# data/test/00073550.png   	극복하다                     	0.7670
# data/test/00073734.png   	신청하다                     	0.9111
# data/test/00073748.png   	지름길                      	0.9325
# data/test/00074036.png   	여위                       	0.5817
# data/test/00074132.png   	충중                       	0.2670
# data/test/00074221.png   	잠자다                      	0.9875
# data/test/00074239.png   	장남                       	0.9944
# data/test/00074314.png   	짙다                       	0.8519
# data/test/00074346.png   	차별                       	0.2888
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00090095.png   	물론                       	0.9653
# data/test/00090101.png   	물질적                      	0.9656
# data/test/00090204.png   	챔피언                      	0.8156
# data/test/00090269.png   	초콜릿                      	0.8774
# data/test/00090285.png   	최소한                      	0.9528
# data/test/00090305.png   	하늘                       	0.9866
# data/test/00090344.png   	한강                       	0.9969
# data/test/00090473.png   	수도                       	0.9968
# data/test/00090673.png   	이대로                      	0.9785
# data/test/00090681.png   	이래서                      	0.9900
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00158708.png   	바가지                      	0.9811
# data/test/00158728.png   	바쁘다                      	0.9974
# data/test/00158740.png   	박사                       	0.9956
# data/test/00158974.png   	공연하다                     	0.9145
# data/test/00159038.png   	괴롭히다                     	0.9853
# data/test/00159048.png   	씻다                       	0.9897
# data/test/00159073.png   	아마도                      	0.9415
# data/test/00159074.png   	아무                       	0.9044
# data/test/00159113.png   	안                        	0.9910
# data/test/00159260.png   	정성                       	0.6066
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00220838.png   	햇볕                       	0.9456
# data/test/00220853.png   	향상되다                     	0.9455
# data/test/00220976.png   	피자                       	0.9981
# data/test/00221052.png   	섹시하다                     	0.8978
# data/test/00221064.png   	소금                       	0.9945
# data/test/00221066.png   	소나무                      	0.9910
# data/test/00221093.png   	인생                       	0.9897
# data/test/00221158.png   	잃어버리다                    	0.5882
# data/test/00221185.png   	잇다                       	0.9620
# data/test/00221187.png   	잊어버리다                    	0.6257
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00225591.png   	붙잡다                      	0.9384
# data/test/00225605.png   	비다                       	0.9889
# data/test/00225788.png   	마디                       	0.5718
# data/test/00225816.png   	돈                        	0.5597
# data/test/00225863.png   	되돌리다                     	0.8057
# data/test/00225949.png   	방식                       	0.9957
# data/test/00225980.png   	실로                       	0.9947
# data/test/00226136.png   	구루시다                     	0.0329
# data/test/00226185.png   	타분                       	0.7187
# data/test/00226465.png   	포로                       	0.6745
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00300824.png   	어제                       	0.9591
# data/test/00300892.png   	안주                       	0.9959
# data/test/00300914.png   	압력                       	0.4760
# data/test/00300920.png   	앞문                       	0.9996
# data/test/00301060.png   	비교적                      	0.9933
# data/test/00301089.png   	가득                       	0.9804
# data/test/00301094.png   	가령                       	0.9643
# data/test/00301177.png   	떠나다                      	0.8765
# data/test/00301195.png   	또환                       	0.8794
# data/test/00301306.png   	동시                       	0.9929
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00304928.png   	차남                       	0.7673
# data/test/00305089.png   	갈비탕                      	0.9021
# data/test/00305193.png   	귀하다                      	0.9506
# data/test/00305460.png   	선원                       	0.9934
# data/test/00305493.png   	볶음                       	0.7108
# data/test/00305549.png   	부정하다                     	0.7416
# data/test/00305632.png   	남다                       	0.8640
# data/test/00305728.png   	다름없다                     	0.9298
# data/test/00305878.png   	예컨대                      	0.9802
# data/test/00306155.png   	배우                       	0.9907
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00322111.png   	예감                       	0.9903
# data/test/00322193.png   	적응                       	0.9262
# data/test/00322222.png   	전반적                      	0.9875
# data/test/00322332.png   	말씀                       	0.7398
# data/test/00322379.png   	흉내                       	0.9176
# data/test/00322473.png   	벨트                       	0.5485
# data/test/00322581.png   	닷새                       	0.8318
# data/test/00322667.png   	엄청나다                     	0.8387
# data/test/00322685.png   	에어컨                      	0.6422
# data/test/00322736.png   	애정                       	0.9907
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00327233.png   	부담하다                     	0.3860
# data/test/00327249.png   	부산                       	0.9928
# data/test/00327296.png   	끼우다                      	0.8873
# data/test/00327305.png   	나란히                      	0.4188
# data/test/00327440.png   	다르다                      	0.8056
# data/test/00327619.png   	오빠                       	0.9713
# data/test/00327837.png   	흔들다                      	0.5893
# data/test/00327885.png   	버려지다                     	0.2295
# data/test/00328006.png   	달려오다                     	0.9895
# data/test/00328021.png   	담당                       	0.9311
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00332846.png   	나들이                      	0.9841
# data/test/00332981.png   	다듬다                      	0.9661
# data/test/00333031.png   	듣다                       	0.4690
# data/test/00333220.png   	전세                       	0.9983
# data/test/00333234.png   	전통문화                     	0.7606
# data/test/00333326.png   	말씀                       	0.9626
# data/test/00333554.png   	달리하다                     	0.8323
# data/test/00333604.png   	어떡하다                     	0.8469
# data/test/00333696.png   	앉다                       	0.9070
# data/test/00333815.png   	분포하다                     	0.7546
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00351431.png   	들이다                      	0.9970
# data/test/00351438.png   	등                        	0.9650
# data/test/00351614.png   	전자                       	0.9991
# data/test/00351756.png   	휴식                       	0.9738
# data/test/00351802.png   	배추                       	0.9954
# data/test/00351820.png   	버터                       	0.9512
# data/test/00351955.png   	담요                       	0.9731
# data/test/00351979.png   	대구                       	0.9994
# data/test/00352222.png   	불안                       	0.9959
# data/test/00352346.png   	관편하다                     	0.2319
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00367794.png   	서양                       	0.9908
# data/test/00367879.png   	부대                       	0.9911
# data/test/00368018.png   	놈                        	0.9930
# data/test/00368054.png   	눈앞                       	0.9651
# data/test/00368056.png   	뉴스                       	0.9867
# data/test/00368110.png   	둘                        	0.8074
# data/test/00368190.png   	영역                       	0.9898
# data/test/00368236.png   	예측하다                     	0.6872
# data/test/00368388.png   	마찬가지                     	0.8629
# data/test/00368390.png   	마치                       	0.5602
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00372769.png   	창                        	0.9876
# data/test/00372779.png   	창피하다                     	0.5828
# data/test/00372808.png   	머리카락                     	0.9147
# data/test/00384633.png   	갈아타다                     	0.9629
# data/test/00384850.png   	순수하다                     	0.9352
# data/test/00385009.png   	보장                       	0.9996
# data/test/00385106.png   	끊임없다                     	0.4623
# data/test/00385155.png   	낚싯대                      	0.9576
# data/test/00385274.png   	영남                       	0.9085
# data/test/00385338.png   	오래도록                     	0.5700
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00401441.png   	선언하다                     	0.8561
# data/test/00401481.png   	본사                       	0.9796
# data/test/00401568.png   	나누어지다                    	0.9142
# data/test/00401632.png   	논의하다                     	0.8086
# data/test/00401703.png   	다녀가다                     	0.9191
# data/test/00401916.png   	적히다                      	0.9967
# data/test/00402099.png   	흐려지다                     	0.8942
# data/test/00402170.png   	벌금                       	0.9522
# data/test/00402243.png   	다행                       	0.9961
# data/test/00402358.png   	어쩜                       	0.9201
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00407046.png   	부동산                      	0.9146
# data/test/00407063.png   	부서지다                     	0.4902
# data/test/00407099.png   	끝나다                      	0.9840
# data/test/00407138.png   	낚시                       	0.8672
# data/test/00407183.png   	놀이터                      	0.7388
# data/test/00407212.png   	눈길                       	0.9966
# data/test/00407292.png   	뒤습                       	0.1769
# data/test/00407304.png   	들르다                      	0.8211
# data/test/00407329.png   	디스크                      	0.5338
# data/test/00407351.png   	영남                       	0.9693
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00411856.png   	팩                        	0.8108
# data/test/00411871.png   	잠그다                      	0.9822
# data/test/00412018.png   	참그                       	0.6102
# data/test/00412153.png   	목요일                      	0.9894
# data/test/00412166.png   	감다                       	0.9725
# data/test/00412230.png   	개방하다                     	0.7323
# data/test/00412272.png   	그것                       	0.9992
# data/test/00412361.png   	수출                       	0.9968
# data/test/00412366.png   	수학                       	0.9946
# data/test/00412375.png   	순간적                      	0.9603
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00416723.png   	결과적                      	0.9688
# data/test/00416759.png   	근래                       	0.9831
# data/test/00416784.png   	금연                       	0.9985
# data/test/00416908.png   	신고하다                     	0.9392
# data/test/00416951.png   	지방                       	0.9985
# data/test/00417009.png   	진출하다                     	0.5801
# data/test/00417034.png   	사업                       	0.9881
# data/test/00417102.png   	상당수                      	0.9958
# data/test/00417174.png   	뺏다                       	0.9227
# data/test/00417200.png   	사랑스럽다                    	0.7764
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00421459.png   	접근하다                     	0.7713
# data/test/00421733.png   	할머니                      	0.9835
# data/test/00422050.png   	이민                       	0.9716
# data/test/00422089.png   	이틀                       	0.7798
# data/test/00422151.png   	큰절                       	0.9887
# data/test/00422166.png   	탁                        	0.9547
# data/test/00422205.png   	거절하다                     	0.8589
# data/test/00422237.png   	걷다                       	0.9880
# data/test/00422265.png   	결과                       	0.9880
# data/test/00422277.png   	결코                       	0.8879
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00426717.png   	과학                       	0.9925
# data/test/00426718.png   	과학자                      	0.9829
# data/test/00426742.png   	관찰하다                     	0.8178
# data/test/00426851.png   	몰려오다                     	0.7801
# data/test/00426986.png   	점치                       	0.9377
# data/test/00426991.png   	정하다                      	0.5124
# data/test/00427074.png   	체육                       	0.9881
# data/test/00427100.png   	초청                       	0.8398
# data/test/00427191.png   	한눈                       	0.9879
# data/test/00427217.png   	한편                       	0.9902
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00433396.png   	활동                       	0.9812
# data/test/00433403.png   	활짝                       	0.2893
# data/test/00433469.png   	너무나                      	0.9757
# data/test/00433476.png   	넓히다                      	0.9887
# data/test/00433562.png   	행동하다                     	0.6180
# data/test/00433580.png   	허용                       	0.9894
# data/test/00433811.png   	인상                       	0.9761
# data/test/00433877.png   	잊다                       	0.6033
# data/test/00433970.png   	작은딸                      	0.9821
# data/test/00434012.png   	출연하다                     	0.9485
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00459819.png   	달러                       	0.9863
# data/test/00459901.png   	어쨌든                      	0.9274
# data/test/00459988.png   	앞                        	0.9864
# data/test/00460011.png   	야구장                      	0.9952
# data/test/00460040.png   	양상추                      	0.4977
# data/test/00460274.png   	뚫다                       	0.9312
# data/test/00460289.png   	뜨겁다                      	0.9892
# data/test/00460409.png   	두                        	0.9927
# data/test/00460489.png   	방지하다                     	0.8229
# data/test/00460502.png   	신체                       	0.9910
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00476565.png   	끼                        	0.9191
# data/test/00476785.png   	등록하다                     	0.8806
# data/test/00476985.png   	젊은이                      	0.9763
# data/test/00477004.png   	마음가짐                     	0.5972
# data/test/00477090.png   	후춧가루                     	0.6576
# data/test/00477104.png   	흐르다                      	0.9906
# data/test/00477108.png   	흑인                       	0.9921
# data/test/00477122.png   	흥분하다                     	0.9359
# data/test/00477124.png   	희곡                       	0.9973
# data/test/00477292.png   	담다                       	0.8650
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00481248.png   	통일하다                     	0.8313
# data/test/00481295.png   	파란색                      	0.9935
# data/test/00481298.png   	파악하다                     	0.8944
# data/test/00481301.png   	파터                       	0.9895
# data/test/00481336.png   	잠바                       	0.9609
# data/test/00481556.png   	메다                       	0.9929
# data/test/00481993.png   	보수적                      	0.9496
# data/test/00482037.png   	봉사                       	0.9231
# data/test/00482144.png   	낚싯대                      	0.9281
# data/test/00482189.png   	농구                       	0.9905
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00486807.png   	찌다                       	0.9974
# data/test/00486928.png   	명단                       	0.9762
# data/test/00487032.png   	갖다                       	0.9318
# data/test/00487235.png   	슬그머니                     	0.9509
# data/test/00487249.png   	시각                       	0.9947
# data/test/00487446.png   	꿈속                       	0.9543
# data/test/00487650.png   	뒤쪽                       	0.9579
# data/test/00487821.png   	적히다                      	0.9820
# data/test/00487840.png   	전문                       	0.9982
# data/test/00487935.png   	만들어지다                    	0.7588
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00491709.png   	지켜보다                     	0.3159
# data/test/00492183.png   	장사                       	0.9996
# data/test/00492237.png   	집단적                      	0.9428
# data/test/00492289.png   	찬물                       	0.9868
# data/test/00492420.png   	모처럼                      	0.8466
# data/test/00538929.png   	감상하다                     	0.8140
# data/test/00538986.png   	개방하다                     	0.9313
# data/test/00539032.png   	그냥                       	0.9936
# data/test/00539183.png   	승용차                      	0.9158
# data/test/00539409.png   	나누다                      	0.9497
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00544236.png   	참석자                      	0.9923
# data/test/00544305.png   	메다                       	0.9944
# data/test/00568186.png   	그런데                      	0.9860
# data/test/00568213.png   	그야말로                     	0.7903
# data/test/00568297.png   	스타일                      	0.9923
# data/test/00568495.png   	부자                       	0.9980
# data/test/00568671.png   	다가가다                     	0.6328
# data/test/00568710.png   	둥지                       	0.9906
# data/test/00568738.png   	들여놓다                     	0.6937
# data/test/00568771.png   	딱                        	0.9772
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00574326.png   	감목                       	0.6027
# data/test/00574400.png   	귀가                       	0.9901
# data/test/00574469.png   	그만                       	0.9994
# data/test/00574488.png   	수석                       	0.9995
# data/test/00574656.png   	서쪽                       	0.9997
# data/test/00574715.png   	본성                       	0.9950
# data/test/00574743.png   	부르다                      	0.9632
# data/test/00574977.png   	뒤집다                      	0.9872
# data/test/00575034.png   	딱딱하다                     	0.9577
# data/test/00575146.png   	적응하다                     	0.9349
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00579532.png   	재학                       	0.9937
# data/test/00579593.png   	차라리                      	0.9872
# data/test/00579640.png   	찾다                       	0.9747
# data/test/00579761.png   	감다                       	0.7586
# data/test/00579829.png   	개선하다                     	0.5808
# data/test/00579970.png   	순간적                      	0.9537
# data/test/00579987.png   	숨지다                      	0.9828
# data/test/00579988.png   	숫자                       	0.7279
# data/test/00580108.png   	석                        	0.9891
# data/test/00580118.png   	선배                       	0.9788
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00584646.png   	사진                       	0.9939
# data/test/00584650.png   	사탕                       	0.9674
# data/test/00584689.png   	삼키다                      	0.5938
# data/test/00584726.png   	비싸다                      	0.9774
# data/test/00584964.png   	틈                        	0.8608
# data/test/00585067.png   	재수                       	0.9979
# data/test/00585153.png   	찬성                       	0.9886
# data/test/00585263.png   	모델                       	0.9265
# data/test/00596289.png   	갈등                       	0.9721
# data/test/00596308.png   	감소                       	0.9925
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00599954.png   	접근                       	0.8630
# data/test/00599995.png   	정치                       	0.5816
# data/test/00600121.png   	최고급                      	0.9428
# data/test/00600147.png   	하느님                      	0.9884
# data/test/00600170.png   	학년                       	0.9973
# data/test/00600243.png   	소식                       	0.9949
# data/test/00600410.png   	군인                       	0.9694
# data/test/00600733.png   	걷다                       	0.9932
# data/test/00600763.png   	결국                       	0.9972
# data/test/00600807.png   	근처                       	0.9986
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00605382.png   	의하다                      	0.9997
# data/test/00605412.png   	대여섯                      	0.8779
# data/test/00605874.png   	주차장                      	0.9745
# data/test/00605881.png   	죽이다                      	0.8679
# data/test/00606121.png   	악기                       	0.9892
# data/test/00606128.png   	안기다                      	0.9960
# data/test/00606251.png   	정기                       	0.7940
# data/test/00606301.png   	제발                       	0.9937
# data/test/00606529.png   	소시지                      	0.9989
# data/test/00606681.png   	국사                       	0.9991
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00621622.png   	소                        	0.9983
# data/test/00621632.png   	소년                       	0.9912
# data/test/00621753.png   	잎                        	0.9994
# data/test/00621874.png   	충분히                      	0.9788
# data/test/00621935.png   	유머                       	0.8867
# data/test/00621937.png   	유명하다                     	0.8180
# data/test/00621984.png   	의도적                      	0.9883
# data/test/00622037.png   	대전                       	0.9985
# data/test/00622170.png   	바람직하다                    	0.6902
# data/test/00622309.png   	기원                       	0.9963
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00638615.png   	네                        	0.9885
# data/test/00638790.png   	표현되다                     	0.7702
# data/test/00638802.png   	품질                       	0.9053
# data/test/00638811.png   	포라스픽                     	0.3705
# data/test/00639202.png   	카메라                      	0.7199
# data/test/00639292.png   	이것                       	0.1528
# data/test/00639350.png   	대회                       	0.9805
# data/test/00639353.png   	더                        	0.9704
# data/test/00639511.png   	민간                       	0.9947
# data/test/00639611.png   	동장                       	0.5993
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00645124.png   	피해                       	0.9989
# data/test/00645338.png   	자격                       	0.9255
# data/test/00645372.png   	자판환경                     	0.5320
# data/test/00645494.png   	침착하다                     	0.7776
# data/test/00645527.png   	유적지                      	0.8696
# data/test/00645544.png   	은                        	0.9567
# data/test/00645752.png   	외아툼                      	0.3506
# data/test/00645758.png   	외침                       	0.9895
# data/test/00645834.png   	바나나                      	0.9649
# data/test/00645871.png   	반드시                      	0.8204
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00650552.png   	프랑스                      	0.8681
# data/test/00650698.png   	인천공항                     	0.9371
# data/test/00650858.png   	추다                       	0.9984
# data/test/00651000.png   	음성                       	0.9921
# data/test/00651236.png   	미래                       	0.9982
# data/test/00651241.png   	미소                       	0.9991
# data/test/00651266.png   	밀다                       	0.9701
# data/test/00651392.png   	월드컵                      	0.7853
# data/test/00651406.png   	위법                       	0.9787
# data/test/00651587.png   	증명하다                     	0.8964
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00657243.png   	심각해지다                    	0.7953
# data/test/00657370.png   	주문하다                     	0.8008
# data/test/00657532.png   	넘겨주다                     	0.9083
# data/test/00657560.png   	노력                       	0.9963
# data/test/00657682.png   	평가                       	0.9873
# data/test/00657717.png   	표현되다                     	0.6009
# data/test/00657763.png   	선택                       	0.9960
# data/test/00657859.png   	인물                       	0.9948
# data/test/00657918.png   	일종                       	0.9883
# data/test/00658051.png   	축구장                      	0.8515
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00662339.png   	불다                       	0.9955
# data/test/00662395.png   	땜                        	0.9721
# data/test/00662431.png   	뛰어놀다                     	0.4122
# data/test/00662484.png   	도저히                      	0.7287
# data/test/00662614.png   	밤중                       	0.9811
# data/test/00662645.png   	배구                       	0.9889
# data/test/00662743.png   	조                        	0.9967
# data/test/00662753.png   	조르다                      	0.9749
# data/test/00662759.png   	조선                       	0.9886
# data/test/00662801.png   	좋아하다                     	0.9531
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00668109.png   	반짝거리다                    	0.6485
# data/test/00668281.png   	쓸다                       	0.8615
# data/test/00668404.png   	홍수                       	0.9528
# data/test/00668436.png   	환갑                       	0.6373
# data/test/00668489.png   	내려가다                     	0.9155
# data/test/00668584.png   	해내다                      	0.9970
# data/test/00668627.png   	허락하다                     	0.2853
# data/test/00668708.png   	표정                       	0.9659
# data/test/00668758.png   	선택하다                     	0.6219
# data/test/00668884.png   	일단                       	0.9968
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00673589.png   	싫어지다                     	0.8009
# data/test/00673675.png   	졸리다                      	0.9852
# data/test/00673691.png   	종이컵                      	0.4716
# data/test/00673736.png   	형태                       	0.7313
# data/test/00673875.png   	넉                        	0.9749
# data/test/00673981.png   	허락                       	0.9484
# data/test/00674047.png   	포도주                      	0.7717
# data/test/00674068.png   	푸다                       	0.9836
# data/test/00674342.png   	충분히                      	0.9565
# data/test/00674351.png   	취향                       	0.9898
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00689804.png   	레저                       	0.6868
# data/test/00689862.png   	동대문                      	0.9962
# data/test/00689920.png   	발걸음                      	0.9916
# data/test/00689946.png   	밝다                       	0.8096
# data/test/00689947.png   	밝아지다                     	0.7570
# data/test/00690355.png   	노랫소리                     	0.9543
# data/test/00690395.png   	해석하다                     	0.7216
# data/test/00690581.png   	성                        	0.9646
# data/test/00690631.png   	소개되다                     	0.9510
# data/test/00690821.png   	작은딸                      	0.9821
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00697470.png   	노란색                      	0.9816
# data/test/00697498.png   	항구                       	0.9549
# data/test/00697537.png   	행운                       	0.4892
# data/test/00697606.png   	평양                       	0.9874
# data/test/00697751.png   	소개되다                     	0.9314
# data/test/00697826.png   	일요일                      	0.9940
# data/test/00698011.png   	층                        	0.9924
# data/test/00698039.png   	침착하다                     	0.6598
# data/test/00698095.png   	음료                       	0.9775
# data/test/00698100.png   	음식물                      	0.9742
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00703599.png   	어떡하다                     	0.5842
# data/test/00703628.png   	어쩜                       	0.9200
# data/test/00703694.png   	알                        	0.9717
# data/test/00703696.png   	알려지다                     	0.8655
# data/test/00703772.png   	얘기하다                     	0.8035
# data/test/00703939.png   	각오                       	0.5488
# data/test/00704034.png   	레저                       	0.8940
# data/test/00704116.png   	동화책                      	0.9821
# data/test/00704170.png   	발전하다                     	0.9107
# data/test/00704373.png   	좋다                       	0.9828
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00709254.png   	분포하다                     	0.7805
# data/test/00709339.png   	가르다                      	0.5647
# data/test/00709360.png   	가이드                      	0.9500
# data/test/00709404.png   	팔                        	0.2755
# data/test/00709457.png   	풀다                       	0.2714
# data/test/00709540.png   	종물원                      	0.0838
# data/test/00709669.png   	신체적                      	0.9499
# data/test/00709793.png   	존자하다                     	0.3004
# data/test/00709815.png   	종합                       	0.9710
# data/test/00709925.png   	활발히                      	0.9135
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00715380.png   	노래                       	0.9975
# data/test/00715387.png   	노인                       	0.9973
# data/test/00715486.png   	형부                       	0.9743
# data/test/00715523.png   	포그터                      	0.3165
# data/test/00715668.png   	소득                       	0.8698
# data/test/00715715.png   	일대                       	0.9995
# data/test/00715843.png   	작성                       	0.9930
# data/test/00715885.png   	출발점                      	0.9968
# data/test/00715955.png   	카페                       	0.9805
# data/test/00716014.png   	응답하다                     	0.8248
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00811220.png   	요즈음                      	0.8688
# data/test/00811241.png   	미술관                      	0.9881
# data/test/00811254.png   	민간                       	0.9925
# data/test/00811267.png   	밀접하다                     	0.9551
# data/test/00811288.png   	바람직하다                    	0.7717
# data/test/00811397.png   	위                        	0.9995
# data/test/00811545.png   	중계방송                     	0.6010
# data/test/00811595.png   	지금                       	0.9947
# data/test/00811641.png   	공책                       	0.9773
# data/test/00811750.png   	아울러                      	0.7653
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00816933.png   	월드컵                      	0.9179
# data/test/00816985.png   	기후                       	0.9847
# data/test/00817061.png   	주저앉다                     	0.7137
# data/test/00817125.png   	증거                       	0.9960
# data/test/00817220.png   	관련되다                     	0.9096
# data/test/00817324.png   	안녕히                      	0.9463
# data/test/00817473.png   	점치                       	0.8636
# data/test/00817621.png   	하긴                       	0.5351
# data/test/00817692.png   	한숨                       	0.9994
# data/test/00817752.png   	속옷                       	0.8891
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00822514.png   	기원전                      	0.9861
# data/test/00822611.png   	주한                       	0.9438
# data/test/00822669.png   	증권                       	0.8779
# data/test/00822683.png   	지급                       	0.9800
# data/test/00822685.png   	지나가다                     	0.9561
# data/test/00822691.png   	골치                       	0.9958
# data/test/00822754.png   	관계자                      	0.9935
# data/test/00822766.png   	관리하다                     	0.7783
# data/test/00822787.png   	씨                        	0.9967
# data/test/00822804.png   	아니                       	0.9962
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00827679.png   	내년                       	0.9923
# data/test/00827709.png   	냉장고                      	0.9927
# data/test/00827719.png   	넓어지다                     	0.9231
# data/test/00827757.png   	녹음하다                     	0.4554
# data/test/00827763.png   	함부로                      	0.5926
# data/test/00827894.png   	포함되다                     	0.6512
# data/test/00828022.png   	소                        	0.9991
# data/test/00828294.png   	치우다                      	0.9785
# data/test/00828343.png   	유의하다                     	0.5321
# data/test/00828531.png   	올림픽                      	0.7237
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00865331.png   	벤치                       	0.5069
# data/test/00865473.png   	어려워지다                    	0.5625
# data/test/00865590.png   	앞장서다                     	0.3831
# data/test/00865609.png   	약                        	0.8970
# data/test/00865630.png   	양보하다                     	0.8500
# data/test/00865668.png   	분리                       	0.9551
# data/test/00865864.png   	똑바로                      	0.9783
# data/test/00865888.png   	뜻밖에                      	0.9036
# data/test/00865948.png   	돌리다                      	0.8192
# data/test/00865960.png   	동기                       	0.9983
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00870054.png   	보호하다                     	0.3005
# data/test/00870094.png   	부드럽다                     	0.8049
# data/test/00870185.png   	낚니                       	0.3160
# data/test/00870202.png   	남기다                      	0.9574
# data/test/00870250.png   	놓지다                      	0.3056
# data/test/00870276.png   	늘                        	0.9698
# data/test/00870473.png   	오른손                      	0.9506
# data/test/00870478.png   	오십                       	0.9928
# data/test/00870641.png   	말놈                       	0.6783
# data/test/00870688.png   	흉내                       	0.9095
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00874981.png   	재즈                       	0.8967
# data/test/00875018.png   	짓다                       	0.9757
# data/test/00875047.png   	차례                       	0.9726
# data/test/00875138.png   	멋지다                      	0.9241
# data/test/00875139.png   	멍멍                       	0.9835
# data/test/00875167.png   	몇십                       	0.9223
# data/test/00875175.png   	모래                       	0.9972
# data/test/00876060.png   	감다                       	0.9673
# data/test/00876097.png   	강요하다                     	0.9300
# data/test/00876159.png   	규칙                       	0.9654
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00881352.png   	장점                       	0.9955
# data/test/00881437.png   	차례                       	0.9905
# data/test/00881578.png   	모자라다                     	0.6255
# data/test/00883323.png   	귀엽다                      	0.9382
# data/test/00883465.png   	스무                       	0.9963
# data/test/00883512.png   	새끼                       	0.9790
# data/test/00883635.png   	본길                       	0.6992
# data/test/00883739.png   	나이                       	0.9896
# data/test/00883862.png   	다리                       	0.9960
# data/test/00883873.png   	두드러지다                    	0.2769
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00888173.png   	상대적                      	0.9815
# data/test/00888192.png   	비빔밥                      	0.2082
# data/test/00888329.png   	특징                       	0.9738
# data/test/00888480.png   	집중저                      	0.7558
# data/test/00888499.png   	찌꺼기                      	0.9610
# data/test/00888551.png   	창밖                       	0.9962
# data/test/00888610.png   	메우다                      	0.9861
# data/test/00899709.png   	강수량                      	0.9585
# data/test/00899868.png   	수천                       	0.9966
# data/test/00900068.png   	붉다                       	0.8207
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00904199.png   	건지다                      	0.8541
# data/test/00904200.png   	건축                       	0.9698
# data/test/00904278.png   	글쎄                       	0.7197
# data/test/00904284.png   	금                        	0.9977
# data/test/00904340.png   	기사                       	0.9982
# data/test/00904348.png   	기억먹다                     	0.2856
# data/test/00904386.png   	시집                       	0.9924
# data/test/00904445.png   	지난주                      	0.9938
# data/test/00904567.png   	사회생활                     	0.9224
# data/test/00904587.png   	살아오다                     	0.9548
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00919889.png   	수명                       	0.9981
# data/test/00920013.png   	계속되다                     	0.9212
# data/test/00920077.png   	이놈                       	0.9966
# data/test/00920107.png   	이모                       	0.9795
# data/test/00920166.png   	합람하다                     	0.0422
# data/test/00920251.png   	털                        	0.6158
# data/test/00920632.png   	사소하다                     	0.5212
# data/test/00920672.png   	산속                       	0.9817
# data/test/00920693.png   	삼다                       	0.3938
# data/test/00920716.png   	상상력                      	0.8717
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00926723.png   	기능                       	0.9980
# data/test/00926822.png   	신고                       	0.9985
# data/test/00927052.png   	비추다                      	0.9163
# data/test/00927123.png   	사무소                      	0.9953
# data/test/00927217.png   	열정                       	0.8843
# data/test/00927265.png   	트이다                      	0.9016
# data/test/00927358.png   	장례식                      	0.9222
# data/test/00927383.png   	재밌다                      	0.9594
# data/test/00927408.png   	저런                       	0.9839
# data/test/00927411.png   	저리                       	0.9964
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00989281.png   	외우다                      	0.9942
# data/test/00989284.png   	외출하다                     	0.7422
# data/test/00989289.png   	완발                       	0.9916
# data/test/00989307.png   	욕                        	0.8951
# data/test/00989467.png   	원인                       	0.9938
# data/test/00989473.png   	월드컵                      	0.6287
# data/test/00989478.png   	웬만하다                     	0.7382
# data/test/00989499.png   	위험성                      	0.9479
# data/test/00989585.png   	꽃                        	0.9979
# data/test/00989772.png   	광고                       	0.9490
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00994986.png   	운전                       	0.9551
# data/test/00995086.png   	깊숙이                      	0.9846
# data/test/00995220.png   	지극히                      	0.9797
# data/test/00995282.png   	과일                       	0.9993
# data/test/00995301.png   	관람객                      	0.2994
# data/test/00995452.png   	무료                       	0.9977
# data/test/00995599.png   	제한                       	0.8188
# data/test/00995674.png   	촌스럽다                     	0.4253
# data/test/00995822.png   	소포                       	0.9793
# data/test/00996038.png   	고민하다                     	0.6453
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01012952.png   	제의하다                     	0.9667
# data/test/01013035.png   	추청하다                     	0.6881
# data/test/01013042.png   	총장                       	0.8077
# data/test/01013285.png   	구별되다                     	0.9798
# data/test/01013296.png   	구속되다                     	0.5783
# data/test/01013365.png   	곁                        	0.9907
# data/test/01013433.png   	골                        	0.9511
# data/test/01013457.png   	이롭다                      	0.8044
# data/test/01013530.png   	캠페인                      	0.8054
# data/test/01013610.png   	턱                        	0.8826
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01018402.png   	물거                       	0.9945
# data/test/01018419.png   	점점                       	0.6700
# data/test/01018510.png   	책임                       	0.9161
# data/test/01018597.png   	최악                       	0.6255
# data/test/01018662.png   	한국적                      	0.9685
# data/test/01018691.png   	한참                       	0.9448
# data/test/01018699.png   	함께                       	0.9474
# data/test/01018901.png   	경찰                       	0.9943
# data/test/01018952.png   	고요하다                     	0.9005
# data/test/01019019.png   	이빨                       	0.5087
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01035316.png   	꼴                        	0.7671
# data/test/01035473.png   	과연                       	0.9978
# data/test/01035474.png   	과외                       	0.9981
# data/test/01035656.png   	무용                       	0.9973
# data/test/01035951.png   	한글날                      	0.9582
# data/test/01036011.png   	소중히                      	0.9849
# data/test/01036073.png   	수돗물                      	0.9238
# data/test/01036168.png   	굳히다                      	0.9856
# data/test/01036199.png   	계산                       	0.9949
# data/test/01036382.png   	코피                       	0.9896
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01063925.png   	완성                       	0.9392
# data/test/01063977.png   	요청                       	0.9947
# data/test/01064039.png   	바닷물                      	0.5365
# data/test/01064044.png   	바로                       	0.9945
# data/test/01064065.png   	반                        	0.9375
# data/test/01064111.png   	운동화                      	0.9957
# data/test/01064161.png   	위아래                      	0.9472
# data/test/01064341.png   	증상                       	0.9965
# data/test/01064527.png   	안                        	0.9859
# data/test/01064644.png   	접근                       	0.8620
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01069326.png   	의지                       	0.9956
# data/test/01069446.png   	일통                       	0.6470
# data/test/01069448.png   	올가을                      	0.7922
# data/test/01069493.png   	외부                       	0.9945
# data/test/01069699.png   	위로하다                     	0.9557
# data/test/01069715.png   	기억되다                     	0.4316
# data/test/01069716.png   	기억하다                     	0.8895
# data/test/01069808.png   	꾸준하다                     	0.1821
# data/test/01069830.png   	준비물                      	0.9763
# data/test/01070043.png   	아쉽다                      	0.6556
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01076598.png   	너무                       	0.9506
# data/test/01076620.png   	넷                        	0.7905
# data/test/01076635.png   	노력                       	0.9554
# data/test/01076665.png   	해내다                      	0.9816
# data/test/01076709.png   	허티                       	0.6799
# data/test/01076769.png   	폐지                       	0.9737
# data/test/01076898.png   	세탁                       	0.9828
# data/test/01077012.png   	임신                       	0.9898
# data/test/01077034.png   	잇따르다                     	0.7101
# data/test/01077052.png   	지동                       	0.9821
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01094779.png   	평균                       	0.9686
# data/test/01094878.png   	섭씨                       	0.9632
# data/test/01094960.png   	인상                       	0.8858
# data/test/01095005.png   	일월                       	0.9955
# data/test/01095026.png   	잃다                       	0.9889
# data/test/01095121.png   	작은아버지                    	0.6097
# data/test/01095163.png   	출입국                      	0.9951
# data/test/01095270.png   	은행나무                     	0.8259
# data/test/01095367.png   	대합실                      	0.9245
# data/test/01095568.png   	바로잡다                     	0.9271
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01100028.png   	낱말                       	0.9797
# data/test/01100112.png   	녹이다                      	0.9786
# data/test/01100134.png   	해답                       	0.9913
# data/test/01100311.png   	설날                       	0.9966
# data/test/01100400.png   	인도                       	0.9919
# data/test/01100582.png   	추가하다                     	0.9110
# data/test/01100942.png   	요리사                      	0.9927
# data/test/01101012.png   	바라다                      	0.9965
# data/test/01101021.png   	바싹                       	0.9959
# data/test/01101039.png   	반기다                      	0.9627

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2 python3 demo.py --image_folder data/test --saved_model /content/-deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
    --workers 0 --batch_max_length 50 --imgH 64 --imgW 200
# Out:
# model input parameters 64 200 20 1 512 256 1047 50 TPS ResNet BiLSTM CTC
# loading pretrained model from /content/-deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00013071.png   	수집하다                     	0.9975
# data/test/00013385.png   	나오다                      	0.9500
# data/test/00013531.png   	둘                        	0.9984
# data/test/00013663.png   	오가다                      	0.9996
# data/test/00013951.png   	버려지다                     	0.9841
# data/test/00014062.png   	닫다                       	0.9971
# data/test/00014173.png   	얼다                       	0.9683
# data/test/00014267.png   	약                        	0.9996
# data/test/00014484.png   	간호사                      	0.9992
# data/test/00014794.png   	싫어지다                     	0.9759
# data/test/00014954.png   	호텔                       	0.9976
# data/test/00014983.png   	확대하다                     	0.9974
# data/test/00015054.png   	내리다                      	0.9283
# data/test/00015153.png   	해석하다                     	0.7624
# data/test/00015330.png   	설사                       	0.9994
# data/test/00015709.png   	육적                       	0.6608
# data/test/00016069.png   	용어                       	0.9999
# data/test/00017462.png   	극복                       	0.8997
# data/test/00017557.png   	시대                       	0.9999
# data/test/00017582.png   	시작                       	0.9999
# data/test/00017590.png   	시집                       	0.9998
# data/test/00017787.png   	살림                       	0.9986
# data/test/00017984.png   	연두색                      	0.9371
# data/test/00017986.png   	연락처                      	0.9997
# data/test/00018001.png   	연출                       	0.9999
# data/test/00018113.png   	팩시밀리                     	0.9969
# data/test/00018179.png   	재미없다                     	0.9954
# data/test/00018203.png   	저녁때                      	0.9889
# data/test/00018213.png   	저절로                      	0.7146
# data/test/00018379.png   	모니터                      	0.9997
# data/test/00051539.png   	생방송                      	0.9986
# data/test/00051624.png   	복습                       	0.9992
# data/test/00052104.png   	전용                       	1.0000
# data/test/00052161.png   	마주치다                     	0.9957
# data/test/00052174.png   	막내                       	0.9991
# data/test/00052408.png   	단순히                      	0.9999
# data/test/00052523.png   	언젠가                      	0.9993
# data/test/00052817.png   	가하다                      	0.9996
# data/test/00052830.png   	간섭                       	0.9990
# data/test/00053508.png   	평화롭다                     	0.9875
# data/test/00053539.png   	풀리다                      	0.9982
# data/test/00054108.png   	덕수궁                      	0.9983
# data/test/00054809.png   	묘사하다                     	0.5037
# data/test/00055067.png   	최초                       	1.0000
# data/test/00055165.png   	할인                       	0.9991
# data/test/00056791.png   	그날                       	1.0000
# data/test/00056941.png   	승리하다                     	0.9775
# data/test/00057129.png   	부장                       	1.0000
# data/test/00057172.png   	뇌                        	0.9999
# data/test/00057237.png   	두르다                      	0.9171
# data/test/00057566.png   	말하다                      	0.9965
# data/test/00057567.png   	맑다                       	0.9827
# data/test/00057600.png   	훌륭하다                     	0.9959
# data/test/00057604.png   	휴식                       	0.9991
# data/test/00057795.png   	담                        	0.9998
# data/test/00057890.png   	얼마나                      	0.9997
# data/test/00058458.png   	배경                       	1.0000
# data/test/00058822.png   	노래                       	0.9989
# data/test/00059065.png   	성장                       	0.9998
# data/test/00059083.png   	세수                       	0.9575
# data/test/00059194.png   	일회용품                     	0.9978
# data/test/00059366.png   	치료하다                     	0.9235
# data/test/00059622.png   	완성하다                     	0.6431
# data/test/00059943.png   	꼬리                       	0.9998
# data/test/00059945.png   	꼭                        	0.9999
# data/test/00060531.png   	하나하나                     	0.9976
# data/test/00060802.png   	굽다                       	0.9988
# data/test/00061124.png   	걸치다                      	0.9999
# data/test/00061323.png   	식용유                      	0.9996
# data/test/00061461.png   	사용                       	0.9999
# data/test/00061601.png   	뻗다                       	0.9982
# data/test/00061813.png   	판매되다                     	0.9558
# data/test/00062083.png   	명함                       	0.9998
# data/test/00062380.png   	서적                       	0.9999
# data/test/00062472.png   	부문                       	1.0000
# data/test/00062518.png   	끝없다                      	0.9984
# data/test/00062577.png   	남매                       	0.9997
# data/test/00062653.png   	능동적                      	0.9949
# data/test/00062737.png   	등록                       	0.9924
# data/test/00062956.png   	마요네즈                     	0.9488
# data/test/00063174.png   	보그                       	0.7541
# data/test/00063410.png   	앞쪽                       	1.0000
# data/test/00063533.png   	붐비다                      	0.9900
# data/test/00063707.png   	뜻밖에                      	0.9980
# data/test/00063985.png   	쌍둥이                      	0.9988
# data/test/00064544.png   	일치하다                     	0.9926
# data/test/00064638.png   	작다                       	0.9996
# data/test/00064798.png   	음력                       	1.0000
# data/test/00064850.png   	대도시                      	0.9853
# data/test/00065058.png   	민간                       	0.9998
# data/test/00065267.png   	까닭                       	0.9946
# data/test/00065310.png   	꽤                        	0.9991
# data/test/00065327.png   	주차하다                     	0.9950
# data/test/00065400.png   	지금껏                      	0.9844
# data/test/00065984.png   	경험                       	0.9999
# data/test/00066025.png   	고소하다                     	0.8108
# data/test/00066388.png   	기념                       	0.9991
# data/test/00066526.png   	지다                       	1.0000
# data/test/00066896.png   	토끼                       	0.9975
# data/test/00067082.png   	저번                       	0.9997
# data/test/00069017.png   	갚다                       	0.9968
# data/test/00069025.png   	개발되다                     	0.8409
# data/test/00069084.png   	그때                       	1.0000
# data/test/00069470.png   	나아가다                     	0.9969
# data/test/00069929.png   	많다                       	0.9760
# data/test/00070005.png   	희곡                       	0.9999
# data/test/00070054.png   	벌                        	0.9897
# data/test/00070147.png   	단편                       	0.9998
# data/test/00070345.png   	야                        	0.9871
# data/test/00070426.png   	분필                       	0.9968
# data/test/00070518.png   	가뭄                       	0.9669
# data/test/00070606.png   	똑같다                      	0.9995
# data/test/00070814.png   	방문                       	1.0000
# data/test/00070901.png   	싶다                       	0.9986
# data/test/00071275.png   	허리                       	0.9997
# data/test/00071475.png   	소개                       	0.9999
# data/test/00071599.png   	잇다                       	0.9985
# data/test/00071687.png   	추천                       	0.9990
# data/test/00071965.png   	옥수수                      	0.9997
# data/test/00072328.png   	꽃씨                       	0.9863
# data/test/00072347.png   	주차장                      	0.9977
# data/test/00072444.png   	공군                       	0.9978
# data/test/00072879.png   	촬영                       	0.9965
# data/test/00072920.png   	하지만                      	0.9997
# data/test/00073337.png   	이익                       	0.9996
# data/test/00073438.png   	택시                       	0.9999
# data/test/00073464.png   	거치다                      	0.9981
# data/test/00073734.png   	신청하다                     	0.9951
# data/test/00074239.png   	장남                       	0.9999
# data/test/00086713.png   	섞이다                      	0.9997
# data/test/00086744.png   	보로                       	0.8790
# data/test/00087048.png   	들어주다                     	0.9986
# data/test/00087184.png   	적극적                      	0.9996
# data/test/00087247.png   	전화기                      	0.9998
# data/test/00087252.png   	전후                       	0.9999
# data/test/00087335.png   	말씀하다                     	0.8815
# data/test/00087649.png   	언어                       	0.9999
# data/test/00087667.png   	엄숙하다                     	0.9974
# data/test/00088368.png   	졸음                       	0.6567
# data/test/00088569.png   	넓히다                      	0.9999
# data/test/00088777.png   	피                        	1.0000
# data/test/00088974.png   	임시                       	0.9994
# data/test/00089061.png   	작용                       	0.9998
# data/test/00089063.png   	작은딸                      	0.9998
# data/test/00089141.png   	치아                       	0.9997
# data/test/00089334.png   	덜다                       	0.9944
# data/test/00089521.png   	바치다                      	0.9987
# data/test/00089555.png   	우리                       	1.0000
# data/test/00089599.png   	웃음소리                     	0.9822
# data/test/00089799.png   	즐거워하다                    	0.9935
# data/test/00089803.png   	증가하다                     	0.9004
# data/test/00089842.png   	공급                       	0.9998
# data/test/00090027.png   	못되다                      	0.9993
# data/test/00090066.png   	묵다                       	0.7593
# data/test/00090101.png   	물질적                      	0.9936
# data/test/00090344.png   	한강                       	0.9999
# data/test/00090473.png   	수도                       	1.0000
# data/test/00090686.png   	이렇게                      	0.9999
# data/test/00091085.png   	식다                       	1.0000
# data/test/00091086.png   	식당                       	0.9996
# data/test/00091392.png   	사들이다                     	0.9955
# data/test/00091426.png   	여름철                      	0.9961
# data/test/00091487.png   	연필                       	1.0000
# data/test/00091747.png   	차차                       	0.9998
# data/test/00155649.png   	걔                        	0.9967
# data/test/00155652.png   	거꾸로                      	0.9932
# data/test/00156492.png   	마요네즈                     	0.9974
# data/test/00156666.png   	벌다                       	0.9999
# data/test/00156838.png   	어머니                      	0.9994
# data/test/00156941.png   	앞바다                      	0.9998
# data/test/00157319.png   	동료                       	0.9998
# data/test/00157551.png   	조기                       	0.9999
# data/test/00157628.png   	주스                       	1.0000
# data/test/00157837.png   	해결                       	0.9954
# data/test/00157886.png   	허용                       	0.9999
# data/test/00158120.png   	인쇄                       	0.9993
# data/test/00158168.png   	일정하다                     	0.8496
# data/test/00158515.png   	대표하다                     	0.9970
# data/test/00158728.png   	바쁘다                      	0.9996
# data/test/00159048.png   	씻다                       	0.9993
# data/test/00159073.png   	아마도                      	0.9997
# data/test/00159074.png   	아무                       	1.0000
# data/test/00159285.png   	제과점                      	0.9994
# data/test/00159355.png   	청하다                      	0.9621
# data/test/00159533.png   	소중히                      	0.9997
# data/test/00159839.png   	이야기하다                    	0.9883
# data/test/00160277.png   	지우개                      	0.9998
# data/test/00160366.png   	사진                       	0.9999
# data/test/00160659.png   	투표                       	0.9999
# data/test/00160687.png   	팀                        	0.9985
# data/test/00160726.png   	잘생기다                     	0.6255
# data/test/00160732.png   	잠들다                      	0.9990
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00160751.png   	장기간                      	0.9999
# data/test/00160806.png   	저녁때                      	0.9927
# data/test/00218717.png   	그제야                      	0.9999
# data/test/00218721.png   	수박                       	0.9996
# data/test/00218732.png   	수영장                      	0.9996
# data/test/00218846.png   	생각                       	0.9991
# data/test/00218915.png   	보수적                      	0.9979
# data/test/00219073.png   	날씨                       	0.9997
# data/test/00219130.png   	놔두다                      	0.9974
# data/test/00219486.png   	마크                       	0.9982
# data/test/00219833.png   	언니                       	0.9997
# data/test/00221187.png   	잊어버리다                    	0.9177
# data/test/00221554.png   	온라인                      	0.9987
# data/test/00221579.png   	완성                       	0.8412
# data/test/00221590.png   	왠지                       	0.9917
# data/test/00222256.png   	문                        	0.9999
# data/test/00222292.png   	점심때                      	0.9963
# data/test/00222301.png   	접시                       	0.9997
# data/test/00222461.png   	총리                       	0.9999
# data/test/00222505.png   	하천                       	1.0000
# data/test/00222812.png   	고등학생                     	0.9956
# data/test/00223241.png   	시설                       	0.9998
# data/test/00223305.png   	신사                       	0.9999
# data/test/00223632.png   	역사                       	0.9999
# data/test/00223762.png   	파리                       	0.9999
# data/test/00223840.png   	장인                       	1.0000
# data/test/00223867.png   	저                        	0.9999
# data/test/00224099.png   	감상하다                     	0.9080
# data/test/00224331.png   	스위치                      	0.9998
# data/test/00224500.png   	볼랜                       	0.6754
# data/test/00224710.png   	늦어지다                     	0.8794
# data/test/00225034.png   	막다                       	0.9979
# data/test/00225095.png   	후반                       	0.5801
# data/test/00225980.png   	실로                       	0.9999
# data/test/00226465.png   	포도                       	0.9978
# data/test/00226716.png   	입사                       	0.9999
# data/test/00226739.png   	자기                       	1.0000
# data/test/00226962.png   	의도                       	0.9998
# data/test/00227566.png   	아가씨                      	0.9985
# data/test/00227926.png   	최후                       	0.9999
# data/test/00228029.png   	교류                       	0.9996
# data/test/00228035.png   	교실                       	0.9979
# data/test/00228190.png   	고주                       	1.0000
# data/test/00228466.png   	결승                       	0.9990
# data/test/00228600.png   	시어머니                     	0.9943
# data/test/00228817.png   	살아오다                     	0.9969
# data/test/00228840.png   	상당수                      	0.9997
# data/test/00229011.png   	연락                       	0.9980
# data/test/00229065.png   	통신                       	0.9930
# data/test/00229361.png   	먹이                       	0.9999
# data/test/00299648.png   	감독                       	0.9991
# data/test/00299750.png   	그                        	0.9987
# data/test/00300039.png   	복습하다                     	0.6216
# data/test/00300089.png   	부위                       	0.9999
# data/test/00300263.png   	디자인                      	0.9995
# data/test/00300473.png   	마을                       	0.9997
# data/test/00300633.png   	버터                       	0.9602
# data/test/00300824.png   	어제                       	0.9997
# data/test/00300914.png   	압력                       	0.9976
# data/test/00301060.png   	비교적                      	0.9999
# data/test/00301089.png   	가득                       	0.9999
# data/test/00301195.png   	또한                       	0.9997
# data/test/00301581.png   	좋아하다                     	0.9981
# data/test/00301599.png   	주무시다                     	0.8700
# data/test/00301678.png   	환울                       	0.8893
# data/test/00301719.png   	내과                       	0.9977
# data/test/00301734.png   	내보내다                     	0.9941
# data/test/00302133.png   	일상적                      	0.9994
# data/test/00302144.png   	일일이                      	0.9005
# data/test/00302910.png   	꼭                        	0.9996
# data/test/00302991.png   	즐거움                      	0.9948
# data/test/00303000.png   	증명하다                     	0.8047
# data/test/00303096.png   	관습                       	0.9997
# data/test/00303144.png   	아르바이트                    	0.5733
# data/test/00303680.png   	교류                       	0.9997
# data/test/00303728.png   	구입하다                     	0.8202
# data/test/00304145.png   	근거하다                     	0.9947
# data/test/00304229.png   	기억나다                     	0.9924
# data/test/00304285.png   	식사하다                     	0.9952
# data/test/00304321.png   	신중하다                     	0.9944
# data/test/00304710.png   	톤                        	0.9996
# data/test/00304914.png   	쫓겨나다                     	0.9968
# data/test/00305089.png   	갈비탕                      	0.9987
# data/test/00305493.png   	볶음                       	0.9160
# data/test/00305549.png   	부정하다                     	0.9984
# data/test/00305728.png   	다름없다                     	0.9726
# data/test/00305878.png   	예컨대                      	0.9988
# data/test/00306181.png   	번거롭다                     	0.9954
# data/test/00306453.png   	앓다                       	0.9995
# data/test/00306523.png   	어깨                       	0.9974
# data/test/00306559.png   	분필                       	0.9999
# data/test/00307096.png   	존재                       	0.9989
# data/test/00307338.png   	노트                       	0.9999
# data/test/00307732.png   	잇다                       	0.9971
# data/test/00307996.png   	이곳저곳                     	0.9950
# data/test/00308312.png   	운동장                      	0.9998
# data/test/00308545.png   	증세                       	0.9993
# data/test/00308625.png   	관계없이                     	0.9985
# data/test/00308798.png   	무조건                      	0.9998
# data/test/00309377.png   	이익                       	0.9996
# data/test/00309470.png   	탓                        	0.9986
# data/test/00309473.png   	태아                       	0.9988
# data/test/00309901.png   	사회주의                     	0.9938
# data/test/00310115.png   	연령                       	0.9997
# data/test/00310177.png   	퇴근하다                     	0.9831
# data/test/00310391.png   	차창                       	0.9999
# data/test/00321704.png   	서쪽                       	0.9999
# data/test/00322222.png   	전반적                      	0.9997
# data/test/00322736.png   	애정                       	0.9997
# data/test/00322758.png   	약하다                      	0.9204
# data/test/00322765.png   	양국                       	0.9993
# data/test/00322770.png   	양보                       	1.0000
# data/test/00323395.png   	활기                       	0.9998
# data/test/00323471.png   	넉                        	0.9996
# data/test/00324157.png   	의지                       	0.9987
# data/test/00324187.png   	대신                       	0.9999
# data/test/00324317.png   	외국어                      	0.9998
# data/test/00324372.png   	미안하다                     	0.8962
# data/test/00324402.png   	바가지                      	0.9985
# data/test/00324416.png   	바람                       	1.0000
# data/test/00324849.png   	아니야                      	0.9994
# data/test/00324946.png   	무기                       	1.0000
# data/test/00325222.png   	하얗다                      	0.9982
# data/test/00325300.png   	소비하다                     	0.9553
# data/test/00325397.png   	교사                       	0.9998
# data/test/00325461.png   	국어                       	0.9997
# data/test/00325520.png   	계획                       	0.9997
# data/test/00325625.png   	이십                       	0.9989
# data/test/00325806.png   	검은색                      	0.9992
# data/test/00326284.png   	뿌리                       	0.9998
# data/test/00326544.png   	장래                       	1.0000
# data/test/00326778.png   	모색하다                     	0.9886
# data/test/00326851.png   	강의                       	0.9996
# data/test/00327233.png   	부담하다                     	0.9886
# data/test/00327249.png   	부산                       	1.0000
# data/test/00327296.png   	끼우다                      	0.9976
# data/test/00327305.png   	나란히                      	0.9234
# data/test/00327440.png   	다르다                      	0.5446
# data/test/00327619.png   	오빠                       	0.9998
# data/test/00327885.png   	버려지다                     	0.8998
# data/test/00328006.png   	달려오다                     	0.9999
# data/test/00328064.png   	어려움                      	0.9992
# data/test/00328202.png   	약간                       	1.0000
# data/test/00328369.png   	가상                       	0.9999
# data/test/00328772.png   	쓰레기통                     	0.7972
# data/test/00329205.png   	표현되다                     	0.9654
# data/test/00329288.png   	성장하다                     	0.5415
# data/test/00329333.png   	소리                       	1.0000
# data/test/00329777.png   	더위                       	1.0000
# data/test/00329803.png   	도리어                      	0.9976
# data/test/00330315.png   	공통되다                     	0.8679
# data/test/00330966.png   	구멍                       	0.9997
# data/test/00331185.png   	이자                       	0.9994
# data/test/00331525.png   	시집가다                     	0.9954
# data/test/00331654.png   	진출                       	0.9992
# data/test/00331974.png   	통역                       	0.9804
# data/test/00332027.png   	파일                       	0.9998
# data/test/00332156.png   	집중되다                     	0.9316
# data/test/00332308.png   	몇몇                       	0.9968
# data/test/00332706.png   	섞이다                      	0.9996
# data/test/00332846.png   	나들이                      	0.9993
# data/test/00332981.png   	다듬다                      	0.9982
# data/test/00333220.png   	전세                       	0.9998
# data/test/00333234.png   	전통문화                     	0.9967
# data/test/00333554.png   	달리하다                     	0.5678
# data/test/00333604.png   	어떡하다                     	0.9802
# data/test/00333696.png   	앉다                       	0.9997
# data/test/00333815.png   	분포하다                     	0.9922
# data/test/00333828.png   	불러일으키다                   	0.4845
# data/test/00333974.png   	때문                       	0.9998
# data/test/00333980.png   	떠들썩하다                    	0.9939
# data/test/00334001.png   	뚫다                       	0.9987
# data/test/00334463.png   	확산되다                     	0.9481
# data/test/00334951.png   	일찍                       	0.9993
# data/test/00335017.png   	자리                       	1.0000
# data/test/00335219.png   	음주                       	1.0000
# data/test/00335276.png   	대응                       	0.9997
# data/test/00336044.png   	무리하다                     	0.9942
# data/test/00336133.png   	정상적                      	0.9994
# data/test/00336408.png   	소지품                      	0.9997
# data/test/00336541.png   	국물                       	0.9999
# data/test/00336698.png   	이번                       	1.0000
# data/test/00337228.png   	사용자                      	0.9999
# data/test/00337714.png   	쫓겨나다                     	0.9789
# data/test/00350766.png   	강                        	0.9990
# data/test/00351438.png   	등                        	0.9999
# data/test/00351802.png   	배추                       	0.9997
# data/test/00351820.png   	버터                       	0.9998
# data/test/00352222.png   	불안                       	0.9982
# data/test/00352346.png   	간편하다                     	0.9905
# data/test/00352555.png   	발생                       	0.9996
# data/test/00352602.png   	방지                       	0.9669
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00352684.png   	싹                        	0.9999
# data/test/00352733.png   	조정                       	0.9990
# data/test/00353004.png   	해결                       	0.9997
# data/test/00353224.png   	세계관                      	0.9997
# data/test/00353302.png   	인하                       	0.9998
# data/test/00353399.png   	자랑                       	0.9988
# data/test/00353512.png   	취향                       	0.9990
# data/test/00353638.png   	이것저것                     	0.9932
# data/test/00353661.png   	대신하다                     	0.7139
# data/test/00354299.png   	괴롭히다                     	0.9804
# data/test/00354514.png   	정반대                      	0.9998
# data/test/00354773.png   	소비하다                     	0.9971
# data/test/00354820.png   	손목                       	1.0000
# data/test/00354913.png   	구월                       	0.9999
# data/test/00355154.png   	켜지다                      	0.9995
# data/test/00355159.png   	코드                       	0.9989
# data/test/00355192.png   	킬로미터                     	0.9973
# data/test/00355419.png   	시내                       	1.0000
# data/test/00355587.png   	진하다                      	0.8093
# data/test/00355665.png   	삼국                       	0.9997
# data/test/00355811.png   	여왕                       	0.9997
# data/test/00355833.png   	연결                       	0.9998
# data/test/00355966.png   	판매하다                     	0.9994
# data/test/00367507.png   	같이                       	0.9999
# data/test/00367551.png   	귀찮다                      	0.9975
# data/test/00367613.png   	그만                       	0.9883
# data/test/00367794.png   	서양                       	0.9999
# data/test/00367879.png   	부대                       	1.0000
# data/test/00368018.png   	놈                        	0.9999
# data/test/00368056.png   	뉴스                       	0.9993
# data/test/00368110.png   	둘                        	0.9985
# data/test/00368236.png   	예측하다                     	0.9982
# data/test/00368388.png   	마찬가지                     	0.9687
# data/test/00368390.png   	마치                       	0.9998
# data/test/00368515.png   	배우다                      	0.9964
# data/test/00368589.png   	병실                       	0.9999
# data/test/00368773.png   	엉덩이                      	0.9978
# data/test/00368921.png   	가운데                      	0.9997
# data/test/00369169.png   	발목                       	1.0000
# data/test/00369351.png   	조직                       	0.9998
# data/test/00369905.png   	인연                       	0.9999
# data/test/00370117.png   	충돌하다                     	0.6074
# data/test/00370140.png   	치즈                       	0.9999
# data/test/00370484.png   	밀리미터                     	0.9983
# data/test/00370613.png   	웬만하다                     	0.8850
# data/test/00370722.png   	꽃잎                       	0.9988
# data/test/00370767.png   	중년                       	1.0000
# data/test/00370782.png   	중얼거리다                    	0.9842
# data/test/00370828.png   	곳                        	0.9999
# data/test/00370911.png   	괜히                       	0.7486
# data/test/00371015.png   	몸매                       	0.9995
# data/test/00371076.png   	문학                       	1.0000
# data/test/00371166.png   	제목                       	0.9921
# data/test/00371593.png   	경험하다                     	0.9976
# data/test/00371605.png   	계약                       	1.0000
# data/test/00371774.png   	코너                       	0.9998
# data/test/00371933.png   	경기                       	1.0000
# data/test/00372106.png   	신랑                       	0.9997
# data/test/00372429.png   	여유                       	0.9989
# data/test/00372523.png   	통장                       	0.9997
# data/test/00372552.png   	특징                       	0.9997
# data/test/00372769.png   	창                        	0.9999
# data/test/00384633.png   	갈아타다                     	0.9992
# data/test/00384850.png   	순수하다                     	0.9876
# data/test/00385009.png   	보장                       	1.0000
# data/test/00385106.png   	끊임없다                     	0.9511
# data/test/00385274.png   	영남                       	0.9999
# data/test/00385338.png   	오래도록                     	0.9843
# data/test/00385392.png   	전기                       	1.0000
# data/test/00385545.png   	효율적                      	0.9971
# data/test/00385637.png   	벌다                       	0.9999
# data/test/00385737.png   	달러                       	0.9996
# data/test/00385782.png   	대개                       	0.9999
# data/test/00386277.png   	발전하다                     	0.9938
# data/test/00386343.png   	실례                       	0.9997
# data/test/00386467.png   	종                        	0.9997
# data/test/00386779.png   	현관                       	0.9999
# data/test/00386861.png   	품목                       	0.9934
# data/test/00387087.png   	입장                       	0.9998
# data/test/00387146.png   	자취                       	0.9993
# data/test/00387701.png   	원인                       	1.0000
# data/test/00387750.png   	기초                       	1.0000
# data/test/00388086.png   	문화재                      	0.9996
# data/test/00388100.png   	물속                       	0.9998
# data/test/00388134.png   	정말로                      	0.9995
# data/test/00388401.png   	소스                       	1.0000
# data/test/00388704.png   	이미                       	0.9996
# data/test/00388756.png   	익숙해지다                    	0.9473
# data/test/00388840.png   	탤런트                      	0.9988
# data/test/00388955.png   	근거하다                     	0.9793
# data/test/00389291.png   	삼월                       	0.9998
# data/test/00389511.png   	토끼                       	0.9911
# data/test/00389778.png   	창고                       	1.0000
# data/test/00401282.png   	수험생                      	0.9988
# data/test/00401703.png   	다녀가다                     	0.9553
# data/test/00401916.png   	적히다                      	0.9999
# data/test/00402243.png   	다행                       	0.9997
# data/test/00402582.png   	블라우스                     	0.9900
# data/test/00402674.png   	간단하다                     	0.8275
# data/test/00402883.png   	발견하다                     	0.9549
# data/test/00402981.png   	실제                       	0.9983
# data/test/00403401.png   	현                        	1.0000
# data/test/00403659.png   	일생                       	0.9999
# data/test/00403711.png   	입학                       	0.9996
# data/test/00404249.png   	밖                        	0.9996
# data/test/00404439.png   	꼼짝                       	0.9976
# data/test/00404629.png   	광고                       	0.9998
# data/test/00404940.png   	철저회                      	0.4994
# data/test/00405453.png   	이자                       	0.9985
# data/test/00405553.png   	택시                       	0.9998
# data/test/00405560.png   	터지다                      	0.9989
# data/test/00405592.png   	건너오다                     	0.9948
# data/test/00405835.png   	신비                       	0.5723
# data/test/00405904.png   	직접                       	0.9997
# data/test/00405966.png   	사진기                      	0.9994
# data/test/00405995.png   	살짝                       	0.9987
# data/test/00406004.png   	삼다                       	0.9993
# data/test/00406088.png   	뺏다                       	0.9996
# data/test/00406153.png   	여자                       	0.9996
# data/test/00406635.png   	감싸다                      	0.9990
# data/test/00406834.png   	순수                       	0.9998
# data/test/00406994.png   	보장                       	1.0000
# data/test/00407046.png   	부동산                      	0.9995
# data/test/00407063.png   	부서지다                     	0.8664
# data/test/00407099.png   	끝나다                      	0.9943
# data/test/00407138.png   	낚시                       	0.9997
# data/test/00407212.png   	눈길                       	0.9999
# data/test/00407304.png   	들르다                      	0.9982
# data/test/00407329.png   	디스크                      	0.9978
# data/test/00407431.png   	오십                       	0.9981
# data/test/00407693.png   	뱀                        	0.9992
# data/test/00408048.png   	어깨                       	0.9976
# data/test/00408178.png   	개볍다                      	0.9740
# data/test/00408307.png   	레저                       	0.9962
# data/test/00408495.png   	배다                       	0.6529
# data/test/00409172.png   	인재                       	0.9998
# data/test/00409380.png   	충고                       	0.9999
# data/test/00409640.png   	올리다                      	0.9997
# data/test/00409725.png   	미스                       	1.0000
# data/test/00409840.png   	운명                       	0.9999
# data/test/00410021.png   	줄다                       	0.9999
# data/test/00410180.png   	괴롭히다                     	0.9907
# data/test/00410234.png   	아유                       	0.9999
# data/test/00410347.png   	묻히다                      	0.5638
# data/test/00410385.png   	정당                       	0.9999
# data/test/00410616.png   	한꺼번에                     	0.9953
# data/test/00410795.png   	구입                       	0.9992
# data/test/00410809.png   	국물                       	1.0000
# data/test/00410874.png   	계획                       	0.9996
# data/test/00411070.png   	키우다                      	0.9996
# data/test/00411259.png   	기구                       	0.9999
# data/test/00411601.png   	비하다                      	0.9778
# data/test/00411753.png   	열기                       	0.9999
# data/test/00411781.png   	통과                       	0.9992
# data/test/00411856.png   	팩                        	0.9989
# data/test/00411871.png   	잠그다                      	0.9997
# data/test/00412823.png   	둘째                       	0.9999
# data/test/00413282.png   	변동                       	0.9995
# data/test/00413492.png   	엔진                       	0.9456
# data/test/00413501.png   	안경                       	0.9998
# data/test/00413521.png   	앓다                       	0.9996
# data/test/00413727.png   	가슴속                      	0.9966
# data/test/00413813.png   	뚱뚱하다                     	0.8694
# data/test/00414158.png   	조정하다                     	0.9890
# data/test/00414628.png   	성격                       	1.0000
# data/test/00414779.png   	임신                       	0.9999
# data/test/00415069.png   	이념                       	0.9999
# data/test/00415177.png   	올라가다                     	0.9963
# data/test/00415370.png   	우울하다                     	0.9717
# data/test/00415623.png   	지급                       	0.9995
# data/test/00415957.png   	정치권                      	0.9997
# data/test/00416032.png   	첫째                       	0.9994
# data/test/00416508.png   	이발소                      	0.9991
# data/test/00416619.png   	타락                       	0.9998
# data/test/00416622.png   	타자기                      	0.9939
# data/test/00416723.png   	결과적                      	0.9990
# data/test/00417034.png   	사업                       	1.0000
# data/test/00417102.png   	상당수                      	0.9996
# data/test/00417174.png   	뺏다                       	0.9987
# data/test/00417200.png   	사랑스럽다                    	0.8367
# data/test/00417596.png   	채소                       	0.9999
# data/test/00417922.png   	순식간                      	0.9997
# data/test/00418038.png   	서류                       	0.9997
# data/test/00418476.png   	예술적                      	0.9998
# data/test/00418481.png   	예약하다                     	0.9956
# data/test/00418515.png   	오븐                       	0.9987
# data/test/00418758.png   	힘껏                       	0.9993
# data/test/00418864.png   	다이어트                     	0.9978
# data/test/00418899.png   	달래다                      	0.9998
# data/test/00419097.png   	야하다                      	0.9997
# data/test/00419132.png   	어                        	0.9998
# data/test/00419257.png   	가리다                      	0.9999
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00419336.png   	떠올리다                     	0.9440
# data/test/00419375.png   	뜻대로                      	0.9993
# data/test/00419463.png   	동양                       	0.9999
# data/test/00419691.png   	조사하다                     	0.9892
# data/test/00420960.png   	월세                       	0.9998
# data/test/00420975.png   	위아래                      	0.9995
# data/test/00421127.png   	중소기업                     	0.9962
# data/test/00421297.png   	아랫사람                     	0.9976
# data/test/00421344.png   	안과                       	0.9997
# data/test/00421427.png   	문학                       	0.9999
# data/test/00421733.png   	할머니                      	0.9962
# data/test/00422089.png   	이틀                       	0.9989
# data/test/00422237.png   	걷다                       	0.9986
# data/test/00422265.png   	결과                       	0.9999
# data/test/00422277.png   	결코                       	0.9994
# data/test/00422294.png   	극복하다                     	0.9671
# data/test/00422383.png   	기억나다                     	0.9991
# data/test/00422992.png   	장미                       	0.9993
# data/test/00423109.png   	참되다                      	0.9993
# data/test/00423289.png   	강요하다                     	0.9985
# data/test/00423633.png   	보험                       	0.9951
# data/test/00423704.png   	부족                       	0.9876
# data/test/00423742.png   	나다                       	0.9999
# data/test/00423950.png   	등록                       	0.9999
# data/test/00424371.png   	단순히                      	0.9990
# data/test/00424426.png   	당하다                      	0.9923
# data/test/00424743.png   	가르침                      	0.9963
# data/test/00425218.png   	종합하다                     	0.9984
# data/test/00425301.png   	확대하다                     	0.9814
# data/test/00425755.png   	인터뷰                      	0.9991
# data/test/00425870.png   	자연스럽다                    	0.7325
# data/test/00426435.png   	원                        	0.9993
# data/test/00426449.png   	웨이터                      	0.9992
# data/test/00426742.png   	관찰하다                     	0.9962
# data/test/00426851.png   	몰려오다                     	0.9362
# data/test/00426986.png   	정치                       	0.9999
# data/test/00426991.png   	정하다                      	0.7542
# data/test/00427100.png   	초청                       	0.9984
# data/test/00427191.png   	한눈                       	0.9999
# data/test/00427509.png   	이동                       	0.9999
# data/test/00427768.png   	경계                       	1.0000
# data/test/00427803.png   	글씨                       	0.9997
# data/test/00427850.png   	기록되다                     	0.9983
# data/test/00427851.png   	기록하다                     	0.9956
# data/test/00427971.png   	지나다                      	0.9999
# data/test/00428154.png   	비밀                       	0.9996
# data/test/00428185.png   	빚                        	0.9987
# data/test/00428248.png   	여기                       	1.0000
# data/test/00428252.png   	여덟                       	0.9981
# data/test/00428448.png   	잠바                       	0.9888
# data/test/00428615.png   	창조적                      	0.9998
# data/test/00431305.png   	강아지                      	0.9994
# data/test/00431319.png   	같이                       	0.9994
# data/test/00431411.png   	그려지다                     	0.9332
# data/test/00431569.png   	생각하다                     	0.9952
# data/test/00431890.png   	다가서다                     	0.9893
# data/test/00432228.png   	만지다                      	0.9965
# data/test/00432376.png   	벗다                       	0.9971
# data/test/00432570.png   	얼음                       	0.6881
# data/test/00432580.png   	없다                       	0.9940
# data/test/00432601.png   	여겨지다                     	0.9979
# data/test/00432649.png   	야                        	0.9792
# data/test/00432824.png   	가볍다                      	0.9984
# data/test/00432891.png   	떠나다                      	0.9996
# data/test/00433150.png   	싣다                       	0.9997
# data/test/00433580.png   	허용                       	0.9997
# data/test/00433877.png   	잊다                       	0.8966
# data/test/00433970.png   	작은딸                      	0.9996
# data/test/00434281.png   	올서다                      	0.4946
# data/test/00434295.png   	와                        	0.9998
# data/test/00434316.png   	외국                       	0.6665
# data/test/00434587.png   	김포공항                     	0.9972
# data/test/00434590.png   	깊이                       	1.0000
# data/test/00434731.png   	지난날                      	0.9992
# data/test/00434800.png   	관광버스                     	0.9663
# data/test/00434810.png   	관습                       	0.9996
# data/test/00435038.png   	정말로                      	0.9989
# data/test/00435220.png   	하문                       	1.0000
# data/test/00435307.png   	소식                       	0.8361
# data/test/00436116.png   	진행되다                     	0.9553
# data/test/00436403.png   	열쇠                       	0.9960
# data/test/00436561.png   	장정                       	0.9883
# data/test/00436693.png   	찾아내다                     	0.9971
# data/test/00458744.png   	그대                       	0.9999
# data/test/00458779.png   	그리워하다                    	0.9626
# data/test/00458913.png   	새롭다                      	0.9984
# data/test/00458988.png   	선수                       	0.9998
# data/test/00459371.png   	영화배우                     	0.9825
# data/test/00459519.png   	절                        	0.9999
# data/test/00459600.png   	말씀드리다                    	0.9215
# data/test/00459688.png   	배추                       	0.9997
# data/test/00459762.png   	병원                       	0.9992
# data/test/00460011.png   	야구장                      	0.9999
# data/test/00460502.png   	신체                       	0.9998
# data/test/00460866.png   	노선                       	0.9999
# data/test/00461111.png   	세계적                      	0.9998
# data/test/00461117.png   	세로                       	1.0000
# data/test/00461191.png   	일                        	0.9999
# data/test/00461342.png   	잘리다                      	0.9993
# data/test/00461506.png   	의사                       	1.0000
# data/test/00461520.png   	이                        	0.9999
# data/test/00461693.png   	외할아버지                    	0.9665
# data/test/00461924.png   	준비되다                     	0.8824
# data/test/00462106.png   	아끼다                      	0.9983
# data/test/00462183.png   	목적                       	0.9994
# data/test/00462471.png   	하긴                       	0.9997
# data/test/00462517.png   	한결                       	0.9999
# data/test/00462543.png   	한식                       	1.0000
# data/test/00462592.png   	소형                       	0.9998
# data/test/00462627.png   	솔직히                      	0.9999
# data/test/00462791.png   	고궁                       	0.9982
# data/test/00463230.png   	시외                       	0.9999
# data/test/00463934.png   	참새                       	0.9997
# data/test/00464012.png   	면                        	0.9998
# data/test/00464021.png   	명령어                      	0.9991
# data/test/00476785.png   	등록하다                     	0.5829
# data/test/00477090.png   	후춧가루                     	0.9969
# data/test/00477108.png   	흑인                       	0.9928
# data/test/00477124.png   	희곡                       	0.9995
# data/test/00477297.png   	담요                       	0.9999
# data/test/00477343.png   	어린애                      	0.9971
# data/test/00477486.png   	얇다                       	0.9975
# data/test/00477638.png   	가방                       	1.0000
# data/test/00477811.png   	돌려주다                     	0.9591
# data/test/00477885.png   	발견                       	1.0000
# data/test/00478134.png   	주부                       	1.0000
# data/test/00478139.png   	주어지다                     	0.9718
# data/test/00478233.png   	횡단보도                     	0.9967
# data/test/00478387.png   	항상                       	0.9985
# data/test/00478451.png   	평일                       	0.9991
# data/test/00478730.png   	자극하다                     	0.9093
# data/test/00479155.png   	요구되다                     	0.9749
# data/test/00479216.png   	바                        	0.9998
# data/test/00479385.png   	기획                       	0.9995
# data/test/00479715.png   	악수                       	0.9998
# data/test/00480061.png   	학자                       	0.9999
# data/test/00480097.png   	한잔                       	0.9997
# data/test/00480110.png   	할인                       	0.9982
# data/test/00480247.png   	구성                       	0.9999
# data/test/00480262.png   	국                        	1.0000
# data/test/00480268.png   	국내외                      	0.9999
# data/test/00480310.png   	경제적                      	0.9999
# data/test/00480453.png   	이월                       	0.9999
# data/test/00480534.png   	킬로미터                     	0.9985
# data/test/00480604.png   	건설되다                     	0.6205
# data/test/00481248.png   	통일하다                     	0.9979
# data/test/00481295.png   	파란색                      	0.9936
# data/test/00481298.png   	파악하다                     	0.7100
# data/test/00482189.png   	농구                       	0.9999
# data/test/00482482.png   	전문                       	0.9996
# data/test/00482519.png   	절대                       	1.0000
# data/test/00482639.png   	훨씬                       	0.7507
# data/test/00482800.png   	단순                       	0.9983
# data/test/00482983.png   	암                        	0.9586
# data/test/00483235.png   	갇히다                      	0.9464
# data/test/00483276.png   	뛰다                       	0.9919
# data/test/00483505.png   	신혼부부                     	0.9969
# data/test/00483541.png   	실현하다                     	0.9963
# data/test/00483763.png   	회견                       	0.9999
# data/test/00483781.png   	낫다                       	0.9878
# data/test/00483792.png   	내내                       	0.9999
# data/test/00484053.png   	피우다                      	0.9336
# data/test/00484180.png   	인제                       	0.9988
# data/test/00484696.png   	요                        	0.9997
# data/test/00484949.png   	까다                       	0.9986
# data/test/00485243.png   	아저씨                      	0.9945
# data/test/00485297.png   	묘사하다                     	0.8401
# data/test/00485969.png   	큰길                       	0.9997
# data/test/00486004.png   	태어나다                     	0.9994
# data/test/00486036.png   	걱정                       	0.9995
# data/test/00486248.png   	시청                       	0.9999
# data/test/00486469.png   	사나이                      	0.9981
# data/test/00486807.png   	찌다                       	0.9994
# data/test/00487935.png   	만들어지다                    	0.9877
# data/test/00488288.png   	약간                       	1.0000
# data/test/00488437.png   	가령                       	0.9988
# data/test/00488516.png   	때리다                      	0.9983
# data/test/00488688.png   	반지                       	0.9880
# data/test/00488850.png   	썰렁하다                     	0.8036
# data/test/00489481.png   	일쑤                       	0.9996
# data/test/00489539.png   	자                        	0.9998
# data/test/00489592.png   	작다                       	0.9996
# data/test/00489745.png   	으레                       	0.9997
# data/test/00490112.png   	운동장                      	0.9999
# data/test/00490306.png   	중국집                      	0.9994
# data/test/00490563.png   	못되다                      	0.9997
# data/test/00490713.png   	제시되다                     	0.9854
# data/test/00490856.png   	하필                       	1.0000
# data/test/00491070.png   	구입                       	0.9984
# data/test/00491159.png   	고기                       	0.9999
# data/test/00491173.png   	고하다                      	0.2286
# data/test/00491397.png   	거치다                      	0.9984
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00491562.png   	기쁘다                      	0.9996
# data/test/00491582.png   	시들다                      	0.9997
# data/test/00491664.png   	신중하다                     	0.9994
# data/test/00491695.png   	지우다                      	0.9999
# data/test/00491709.png   	지켜보다                     	0.9970
# data/test/00492237.png   	집단적                      	0.9980
# data/test/00539183.png   	승용차                      	0.9985
# data/test/00539737.png   	오징어                      	0.9725
# data/test/00539900.png   	맘                        	0.9997
# data/test/00539940.png   	흉내                       	0.9985
# data/test/00539941.png   	흐려지다                     	0.6071
# data/test/00540028.png   	벗기다                      	0.9989
# data/test/00540336.png   	양심                       	0.9998
# data/test/00540451.png   	가능                       	1.0000
# data/test/00540473.png   	가만있다                     	0.9781
# data/test/00540535.png   	땅속                       	0.9987
# data/test/00540693.png   	되돌리다                     	0.8774
# data/test/00541248.png   	피                        	1.0000
# data/test/00541275.png   	선호하다                     	0.9924
# data/test/00541451.png   	입국                       	1.0000
# data/test/00541469.png   	있다                       	0.9992
# data/test/00541614.png   	치우다                      	0.9996
# ...
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/00986338.png   	그다지                      	0.9948
# data/test/00986398.png   	수석                       	1.0000
# data/test/00986998.png   	예전                       	0.9998
# data/test/00987025.png   	오른발                      	0.9993
# data/test/00987213.png   	맞은편                      	0.9991
# data/test/00987307.png   	번역                       	0.9993
# data/test/00987378.png   	다이어트                     	0.9880
# data/test/00987532.png   	업종                       	0.9988
# data/test/00987663.png   	부회장                      	0.9998
# data/test/00987738.png   	비디오                      	0.9999
# data/test/00987744.png   	가까워지다                    	0.8346
# data/test/00987849.png   	떠오르다                     	0.8114
# data/test/00988014.png   	반짝거리다                    	0.9954
# data/test/00988043.png   	발전하다                     	0.9902
# data/test/00988046.png   	발표되다                     	0.9977
# data/test/00988246.png   	좋다                       	0.9996
# data/test/00988959.png   	출발                       	0.9958
# data/test/00989103.png   	의식하다                     	0.9990
# data/test/00989181.png   	더더욱                      	0.7581
# data/test/00989192.png   	덕수궁                      	0.9548
# data/test/00989259.png   	왕                        	0.9998
# data/test/00989289.png   	완발                       	0.9986
# data/test/00989473.png   	월드컵                      	0.9954
# data/test/00989585.png   	꽃                        	0.9998
# data/test/00989772.png   	광고                       	0.9999
# data/test/00990231.png   	한순간                      	0.9996
# data/test/00990297.png   	손길                       	0.9999
# data/test/00991574.png   	짜다                       	0.9998
# data/test/00991620.png   	참고하다                     	0.9934
# data/test/00991753.png   	목요일                      	0.9999
# data/test/00991836.png   	개월                       	0.9999
# data/test/00991947.png   	수염                       	0.9994
# data/test/00991997.png   	쉽다                       	0.9993
# data/test/00992407.png   	두다                       	0.9992
# data/test/00992824.png   	배우다                      	0.9984
# data/test/00992856.png   	벌금                       	0.9993
# data/test/00992883.png   	변명                       	0.9998
# data/test/00993145.png   	앨범                       	0.9986
# data/test/00993226.png   	분포하다                     	0.9978
# data/test/00993587.png   	발톱                       	0.9998
# data/test/00993601.png   	밤새                       	0.9998
# data/test/00993806.png   	주름살                      	0.9953
# data/test/00993925.png   	낮추다                      	0.9971
# data/test/00994317.png   	인정받다                     	0.9931
# data/test/00994743.png   	덮이다                      	0.9993
# data/test/00994986.png   	운전                       	0.9998
# data/test/00995086.png   	깊숙이                      	0.9989
# data/test/00995220.png   	지극히                      	0.9995
# data/test/00996038.png   	고민하다                     	0.9982
# data/test/00996195.png   	건조                       	0.9996
# data/test/00996485.png   	지폐                       	0.9991
# data/test/00996628.png   	비만                       	0.9998
# data/test/00997059.png   	차츰                       	0.9992
# data/test/00997181.png   	모색하다                     	0.9648
# data/test/01009310.png   	수염                       	0.9989
# data/test/01009409.png   	새기다                      	0.9993
# data/test/01010193.png   	백두산                      	0.9996
# data/test/01010340.png   	담당하다                     	0.9653
# data/test/01010384.png   	어른                       	0.9997
# data/test/01011411.png   	해외여행                     	0.9990
# data/test/01011473.png   	페인트                      	0.9856
# data/test/01011637.png   	셋째                       	0.9997
# data/test/01011678.png   	인재                       	0.9985
# data/test/01011784.png   	자라나다                     	0.9987
# data/test/01012154.png   	옷차림                      	0.9982
# data/test/01012349.png   	운전                       	0.9999
# data/test/01012682.png   	괜히                       	0.9996
# data/test/01012952.png   	제의하다                     	0.5673
# data/test/01013285.png   	구별되다                     	0.9620
# data/test/01013296.png   	구록되다                     	0.8450
# data/test/01013433.png   	골                        	0.9999
# data/test/01013457.png   	이롭다                      	0.9987
# data/test/01013695.png   	결정되다                     	0.9962
# data/test/01013838.png   	시점                       	1.0000
# data/test/01013852.png   	식다                       	0.9999
# data/test/01014056.png   	삼촌                       	0.4305
# data/test/01014061.png   	상관없이                     	0.9990
# data/test/01014701.png   	강력히                      	0.9987
# data/test/01014740.png   	개선하다                     	0.9932
# data/test/01015202.png   	낡다                       	0.9995
# data/test/01015280.png   	늘리다                      	0.9861
# data/test/01015737.png   	백색                       	0.9996
# data/test/01016144.png   	불다                       	0.9843
# data/test/01016296.png   	떠들다                      	0.9693
# data/test/01016323.png   	뛰어나가다                    	0.9930
# data/test/01016329.png   	뛰어다니다                    	0.8727
# data/test/01016517.png   	밥솥                       	0.9991
# data/test/01016533.png   	방지하다                     	0.9896
# data/test/01016536.png   	방해하다                     	0.9984
# data/test/01016537.png   	방향                       	0.9998
# data/test/01016667.png   	조화되다                     	0.9849
# data/test/01016899.png   	년생                       	0.9827
# data/test/01017404.png   	출구                       	0.9999
# data/test/01017472.png   	칫술                       	0.5623
# data/test/01017612.png   	대표하다                     	0.9941
# data/test/01017618.png   	대학생                      	0.9997
# data/test/01017731.png   	외제                       	0.9992
# data/test/01018341.png   	묘사                       	0.9984
# data/test/01018510.png   	책임                       	0.9997
# data/test/01018662.png   	한국적                      	0.8248
# data/test/01018691.png   	한창                       	0.9999
# data/test/01018952.png   	고요하다                     	0.5082
# data/test/01019660.png   	빗줄기                      	0.9987
# data/test/01020128.png   	먹다                       	0.9999
# data/test/01032562.png   	느낌                       	0.9986
# data/test/01032569.png   	늘어놓다                     	0.9989
# data/test/01032739.png   	예컨대                      	0.9991
# data/test/01032901.png   	막다                       	0.9996
# data/test/01032952.png   	맡기다                      	0.9995
# data/test/01033247.png   	언제                       	0.9996
# data/test/01033548.png   	각오                       	0.9998
# data/test/01033636.png   	라인                       	0.9997
# data/test/01033999.png   	주름살                      	0.9952
# data/test/01034228.png   	해당되다                     	0.9983
# data/test/01034443.png   	세금                       	1.0000
# data/test/01034539.png   	일손                       	0.9998
# data/test/01034571.png   	임시                       	0.9996
# data/test/01034600.png   	자                        	0.9997
# data/test/01034713.png   	춥다                       	0.9969
# data/test/01034733.png   	치료                       	0.4820
# data/test/01034854.png   	이것                       	0.9997
# data/test/01034964.png   	온라인                      	0.9983
# data/test/01035066.png   	미워하다                     	0.8746
# data/test/01035126.png   	박스                       	0.9999
# data/test/01035316.png   	꼴                        	0.9988
# data/test/01035474.png   	과외                       	0.9999
# data/test/01035656.png   	무용                       	1.0000
# data/test/01036073.png   	수돗물                      	0.9996
# data/test/01036393.png   	크림                       	0.9992
# data/test/01036424.png   	탓                        	0.9996
# data/test/01036473.png   	건넌방                      	0.9971
# data/test/01060927.png   	강변                       	0.9999
# data/test/01060943.png   	갖추다                      	0.9988
# data/test/01061436.png   	남북                       	0.9999
# data/test/01061510.png   	능력                       	0.9981
# data/test/01061784.png   	전환하다                     	0.9981
# data/test/01062004.png   	베다                       	0.9999
# data/test/01062036.png   	보내오다                     	0.9932
# data/test/01062086.png   	달러                       	0.9995
# data/test/01062129.png   	대가                       	1.0000
# data/test/01062208.png   	없어지다                     	0.8920
# data/test/01062423.png   	가늘다                      	0.9992
# data/test/01062486.png   	각종                       	0.9998
# data/test/01062576.png   	레몬                       	0.9987
# data/test/01062896.png   	졸다                       	0.7859
# data/test/01063081.png   	내적                       	1.0000
# data/test/01063531.png   	있다                       	0.9981
# data/test/01063583.png   	자체                       	0.9999
# data/test/01063859.png   	더욱이                      	0.9981
# data/test/01063881.png   	도달하다                     	0.9897
# data/test/01063977.png   	요청                       	0.9998
# data/test/01064161.png   	위아래                      	0.9992
# data/test/01064341.png   	증상                       	0.9998
# data/test/01064722.png   	제작                       	0.9999
# data/test/01064829.png   	필자                       	0.9999
# data/test/01065003.png   	수고하다                     	0.9991
# data/test/01065085.png   	국산                       	1.0000
# data/test/01065150.png   	고교                       	0.9989
# data/test/01065152.png   	고구마                      	0.9988
# data/test/01065370.png   	탤런트                      	0.9965
# data/test/01065467.png   	경계                       	1.0000
# data/test/01065513.png   	금연                       	0.9999
# data/test/01065586.png   	시선                       	0.9999
# data/test/01066029.png   	열쇠                       	0.9987
# data/test/01066054.png   	통과하다                     	0.8551
# data/test/01066708.png   	상징하다                     	0.8760
# data/test/01067096.png   	둥글다                      	0.9960
# data/test/01067135.png   	등등                       	0.9852
# data/test/01067290.png   	전라도                      	0.9996
# data/test/01068200.png   	동창                       	0.9998
# data/test/01068266.png   	밝혀내다                     	0.9872
# data/test/01068584.png   	최전                       	0.6058
# data/test/01068644.png   	넓어지다                     	0.9139
# data/test/01068731.png   	행동하다                     	0.5417
# data/test/01068829.png   	표준                       	0.9886
# data/test/01069315.png   	의복                       	0.9998
# data/test/01069446.png   	온통                       	0.7423
# data/test/01069493.png   	외부                       	0.9998
# data/test/01069716.png   	기억하다                     	0.8954
# data/test/01070138.png   	무조건                      	0.9977
# data/test/01070414.png   	학위                       	0.9997
# data/test/01071006.png   	기막히다                     	0.9761
# data/test/01071067.png   	시험                       	0.9999
# data/test/01071151.png   	지적                       	0.9999
# data/test/01071207.png   	집                        	0.9995
# data/test/01071283.png   	상당                       	1.0000
# data/test/01071346.png   	빨간색                      	0.9996
# data/test/01071623.png   	장래                       	0.9999
# data/test/01071648.png   	재미없다                     	0.9884
# data/test/01071865.png   	모자                       	0.9999
# data/test/01074464.png   	개별                       	0.9998
# data/test/01074520.png   	그래                       	0.4660
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# data/test/01074681.png   	새다                       	0.9897
# data/test/01074832.png   	부분                       	0.9998
# data/test/01075123.png   	딸기                       	0.9957
# data/test/01075253.png   	편망하다                     	0.8954
# data/test/01075405.png   	후춧가루                     	0.9952
# data/test/01075700.png   	얼음                       	0.7479
# data/test/01075810.png   	양복                       	1.0000
# data/test/01075933.png   	가득                       	0.9999
# data/test/01075935.png   	가득히                      	0.9969
# data/test/01076383.png   	조선                       	0.9999
# data/test/01076408.png   	좁히다                      	0.9977
# data/test/01076635.png   	노력                       	0.9877
# data/test/01076665.png   	해내다                      	0.9998
# data/test/01076769.png   	폐지                       	0.9973
# data/test/01076898.png   	세탁                       	1.0000
# data/test/01077034.png   	잇따르다                     	0.8441
# data/test/01077052.png   	지동                       	0.9982
# data/test/01077125.png   	축구공                      	0.9990
# data/test/01077421.png   	옮기다                      	0.9992
# data/test/01077457.png   	외우다                      	0.9962
# data/test/01077733.png   	깜짝                       	0.9996
# data/test/01077895.png   	공장                       	1.0000
# data/test/01078083.png   	무려                       	0.9999
# data/test/01078294.png   	초보                       	0.9999
# data/test/01078317.png   	최대                       	0.9994
# data/test/01078480.png   	손뼉                       	0.9994
# data/test/01078704.png   	골고루                      	0.9996
# data/test/01078979.png   	기숙사                      	0.9362
# data/test/01078993.png   	시도하다                     	0.9556
# data/test/01079111.png   	지위                       	0.9999
# data/test/01092797.png   	새소리                      	0.9997
# data/test/01092900.png   	복숭아                      	0.9853
# data/test/01093543.png   	별다르다                     	0.9715
# data/test/01093963.png   	가르다                      	0.9976
# data/test/01094307.png   	실리다                      	0.9995
# data/test/01094509.png   	화려하다                     	0.9929
# data/test/01094779.png   	평균                       	0.9968
# data/test/01095121.png   	작은아버지                    	0.9890
# data/test/01095367.png   	대합실                      	0.9961
# data/test/01095568.png   	바로잡다                     	0.9971
# data/test/01095680.png   	꼭대기                      	0.9962
# data/test/01095859.png   	관람객                      	0.9986
# data/test/01095988.png   	못                        	0.9998
# data/test/01096012.png   	우리                       	0.5828
# data/test/01096022.png   	무용가                      	0.9976
# data/test/01096396.png   	손                        	0.9999
# data/test/01096471.png   	교훈                       	0.9989
# data/test/01096649.png   	이렇다                      	0.9998
# data/test/01096787.png   	탈출하다                     	0.9884
# data/test/01097066.png   	신고하다                     	0.9928
# data/test/01097091.png   	신청                       	0.9998
# data/test/01097126.png   	지저분하다                    	0.9958
# data/test/01097224.png   	산길                       	0.9998
# data/test/01097282.png   	비밀                       	0.9988
# data/test/01097373.png   	여관                       	0.9999
# data/test/01097649.png   	저녁때                      	0.9801
# data/test/01097669.png   	집중적                      	0.9996
# data/test/01097778.png   	머물다                      	0.9975
# data/test/01097886.png   	갑                        	0.9995
# data/test/01098817.png   	만들어지다                    	0.5453
# data/test/01098983.png   	변동                       	0.9997
# data/test/01099616.png   	동서                       	0.9999
# data/test/01099849.png   	조사하다                     	0.9902
# data/test/01099861.png   	조카                       	0.9996
# data/test/01100311.png   	설날                       	0.9998
# data/test/01101021.png   	바싹                       	0.9997
# data/test/01101076.png   	우편                       	0.9999
# data/test/01101210.png   	깨소금                      	0.9997
# data/test/01101337.png   	곳                        	0.9999
# data/test/01101789.png   	최소                       	1.0000
# data/test/01102173.png   	골목                       	0.9999

# %%
ouput = !CUDA_VISIBLE_DEVICES=0,1,2 python3 demo.py --image_folder data/real_test --saved_model /content/-deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
    --workers 0  --imgH 64 --imgW 200

# %%
from IPython.core.display import display, HTML
from PIL import Image
import base64
import io
import pandas as pd

data = pd.DataFrame()
for ind, row in enumerate(ouput[ouput.index('image_path               \tpredicted_labels         \tconfidence score')+2:]):
  row = row.split('\t')
  filename = row[0].strip()
  label = row[1].strip()
  conf = row[2].strip()
  img = Image.open(filename)
  img_buffer = io.BytesIO()
  img.save(img_buffer, format="PNG")
  imgStr = base64.b64encode(img_buffer.getvalue()).decode("utf-8") 

  data.loc[ind, 'img'] = '<img src="data:image/png;base64,{0:s}">'.format(imgStr)
  data.loc[ind, 'id'] = filename
  data.loc[ind, 'label'] = label
  data.loc[ind, 'conf'] = conf

html_all = data.to_html(escape=False)
display(HTML(html_all))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>img</th>
#       <th>id</th>
#       <th>label</th>
#       <th>conf</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/png;base64,..."></td>
#       <td>data/real_test/고기.png</td>
#       <td>고기</td>
#       <td>1.0000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/png;base64,..."></td>
#       <td>data/real_test/그래.png</td>
#       <td>그래</td>
#       <td>0.9999</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/png;base64,..."></td>
#       <td>data/real_test/똑똑이.png</td>
#       <td>똑같미</td>
#       <td>0.3291</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/png;base64,..."></td>
#       <td>data/real_test/솔트룩스.png</td>
#       <td>슬프토스</td>
#       <td>0.0814</td>
#     </tr>
#   </tbody>
# </table>
